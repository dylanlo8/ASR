# %%
# !pip install libretranslatepy
# Out:
# Collecting libretranslatepy
#   Downloading libretranslatepy-2.1.4-py3-none-any.whl.metadata (785 bytes)
# Downloading libretranslatepy-2.1.4-py3-none-any.whl (3.5 kB)
# Installing collected packages: libretranslatepy
# Successfully installed libretranslatepy-2.1.4

# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import torch
import pandas as pd
from pydub import AudioSegment
import string

# %%
# Retrieve .txt files
def list_files_in_directory(directory):
    file_list = []
    for filename in os.listdir(directory):
        # Only pick up files with .txt extensions (transcript)
        if filename.endswith(".txt"):
            file_list.append(filename.replace(".txt", ""))
    return file_list

# Create the dataframe
def get_reference_df(directory, audio_txt_file):
    txt_file_path = os.path.join(directory, audio_txt_file + ".txt")
    columns = ["start_time", "end_time", "reference"]
    # Read the text file into a DataFrame
    df = pd.read_csv(txt_file_path, sep="\t", header=None, names=columns, quoting=3)

    # Add file name
    df.insert(0, 'file_name', pd.Series([audio_txt_file] * len(df)))

    # Remove quotation marks
    df['reference'] = df['reference'].apply(lambda x : x.replace('"',""))
    
    return df

# Trim audio files
def trim_wav_by_timestamps(directory, wav_file_name, reference_df):
    # Create the output directory if it doesn't exist
    output_dir = "data/sub/"
    os.makedirs(output_dir, exist_ok=True)
    wav_file = os.path.join(directory, wav_file_name + ".wav") # get into data file
    
    # Load the WAV file
    audio = AudioSegment.from_wav(wav_file)
    
    def trim_segments(row):
        start_ms = float(row['start_time']) * 1000  # Convert start time to milliseconds
        end_ms = float(row['end_time']) * 1000      # Convert end time to milliseconds
        trimmed_segment = audio[start_ms:end_ms]
    
        return trimmed_segment
    
    # Iterate over timestamps and trim the audio
    for i, row in reference_df.iterrows():
        trimmed_segment = trim_segments(row)
        output_file = os.path.join(output_dir, wav_file_name + "_" f"trimmed_segment_{i+1}.wav")
        trimmed_segment.export(output_file, format="wav")
        reference_df.at[i, 'trimmed_segment_path'] = output_file
    
    return reference_df

# Helper function to remove punctuations from original subtitles
def strip_punctuation(text):
    # Create a translation table that maps each punctuation character to None
    translator = str.maketrans('', '', string.punctuation)
    # Use the translation table to remove all punctuation from the text
    return text.translate(translator)

# Filter english text and append it to dataframe
def filter_subs_by_lang(reference_df):
    # Helper function that is applied across the rows to filter english text only
    
    def filter_english_only(text):
        # Define a regex pattern to match English words
        english_pattern = re.compile(r'\b[A-Za-z]+\b')
        # Find all English words in the text
        english_words = english_pattern.findall(text)
        # Join the English words into a single string
        english_text = ' '.join(english_words)
        return english_text
    
    def filter_thai_only(text):
        # Remove punctuation from text
        text = strip_punctuation(text)
        # Tokenize the string, split by spaces
        list_of_words = text.split()
        # Define a regex pattern to match English words
        english_pattern = re.compile(r'\b[A-Za-z]+\b')
        # Find all English words in the text
        english_words = english_pattern.findall(text)
        # Find all Thai words
        thai_words = [word for word in list_of_words if word not in english_words]
        # Concatenate the Thai words into a string
        thai_text = ' '.join(thai_words)
        # Return thai string
        return thai_text

    reference_df['eng_reference'] = reference_df['reference'].apply(filter_english_only)
    reference_df['thai_reference'] = reference_df['reference'].apply(filter_thai_only)

    return reference_df


def get_combined_audio_table(directory, file_names):
    combined_df = pd.DataFrame()
    for file_name in file_names:
        # Reads the transcript dataframe which has the start_time, end_time of each transcript
        reference_df = get_reference_df(directory, file_name)

        # Split subtitles by language
        reference_df = filter_subs_by_lang(reference_df)

        # Remove 'reference' column
        reference_df = reference_df.drop('reference', axis=1)

        # Uncomment to trim all the .wav file according to the subtitles start_time and end_time
        reference_df = trim_wav_by_timestamps(directory, file_name, reference_df)
        
        # Append the processed DataFrame to the combined DataFrame
        combined_df = pd.concat([combined_df, reference_df], ignore_index=True)

        # Comment out this section if not required
        #combined_df = combined_df.drop(['file_name', 'start_time', 'end_time'], axis=1)
    
    return combined_df

directory = os.path.join(os.getcwd(), "unprocessed_data/")
file_names = list_files_in_directory(directory)
combined_df = get_combined_audio_table(directory, file_names)
combined_df
# Out:
#          file_name  start_time  end_time eng_reference  \
# 0      sVnGI2S_OuA       0.000     1.768
# 1      sVnGI2S_OuA       1.768     2.869
# 2      sVnGI2S_OuA       2.869     4.938
# 3      sVnGI2S_OuA       5.105     6.706
# 4      sVnGI2S_OuA       6.706     8.341
# ...            ...         ...       ...           ...
# 19063  eVbLXknPOdk      70.640    72.440
# 19064  eVbLXknPOdk      72.440    75.280
# 19065  eVbLXknPOdk      82.360    86.880
# 19066  eVbLXknPOdk      86.880    89.120
# 19067  eVbLXknPOdk      89.120    92.720
#
#                                        thai_reference  \
# 0                        เหตุการณ์มันผ่านมาแล้ว 10 ปี
# 1                                    บางคนปล่อยไม่ได้
# 2                   นั้นเครื่องมือที่จะหยุดมันได้ คือ
# 3                                             ลมหายใจ
# 4                          ถ้าพี่เอาน้องทุกคนมาบอกว่า
# ...                                               ...
# 19063                        แล้วเราจ่ายไหว เราก็จ่าย
# 19064        แล้วอะไรทำให้พฤติกรรมการเงินเราเปลี่ยนไป
# 19065   เล่าให้ฟังนิดนึงว่าเราคิดถึงจุดที่มาถึงวันนี้
# 19066                     ที่กำลังจะเกิดขึ้นในปี 2025
# 19067  ก็คือตัดสินใจยุติบทบาทของวง ตั้งแต่เมื่อไหร่คะ
#
#                               trimmed_segment_path
# 0       data/sub/sVnGI2S_OuA_trimmed_segment_1.wav
# 1       data/sub/sVnGI2S_OuA_trimmed_segment_2.wav
# 2       data/sub/sVnGI2S_OuA_trimmed_segment_3.wav
# 3       data/sub/sVnGI2S_OuA_trimmed_segment_4.wav
# 4       data/sub/sVnGI2S_OuA_trimmed_segment_5.wav
# ...                                            ...
# 19063  data/sub/eVbLXknPOdk_trimmed_segment_25.wav
# 19064  data/sub/eVbLXknPOdk_trimmed_segment_26.wav
# 19065  data/sub/eVbLXknPOdk_trimmed_segment_27.wav
# 19066  data/sub/eVbLXknPOdk_trimmed_segment_28.wav
# 19067  data/sub/eVbLXknPOdk_trimmed_segment_29.wav
#
# [19068 rows x 6 columns]

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M", use_auth_token=True, src_lang="tha_Thai")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M", use_auth_token=True).to("cuda").eval()
# Out:
# /home/dhuser/Desktop/.venv/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:757: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /home/dhuser/Desktop/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/dhuser/Desktop/.venv/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:468: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(

# %%
def translate_to_thai(row):
    article = row['thai_reference']
    inputs = tokenizer(article, return_tensors="pt").to("cuda")
    translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.lang_code_to_id["eng_Latn"], max_length=30)
    return tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]

# %%
from tqdm import tqdm
tqdm.pandas()

nllb_translation = combined_df.progress_apply(translate_to_thai, axis=1)
# Out:
# 100%|██████████| 19068/19068 [25:45<00:00, 12.34it/s]

# %%
nllb_translation
# Out:
# 0                                     It's been ten years.
# 1                                Some people can't let go.
# 2                              That's the tool to stop it.
# 3                                                The wind.
# 4              If you bring all your brothers and sisters,
#                                ...
# 19063                          And we can pay. We can pay.
# 19064              So what changed our financial behavior?
# 19065    Let me tell you a little bit about how we're t...
# 19066                      That's going to happen in 2025.
# 19067          It's about when you decide to end the band.
# Length: 19068, dtype: object

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("translation", model="Helsinki-NLP/opus-mt-th-en", device = 0)
# Out:
# /home/dhuser/Desktop/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
helsinki_translation = pipe(combined_df['thai_reference'].tolist())

# %%
helsinki_translation
# Out:
# [{'translation_text': "It's been 10 years."},
#  {'translation_text': "Some people can't let go."},
#  {'translation_text': "That's the tool to stop it."},
#  {'translation_text': 'Breathe.'},
#  {'translation_text': 'If you bring all your sisters to me,'},
#  {'translation_text': 'Hey, sis.'},
#  {'translation_text': 'Focus.'},
#  {'translation_text': 'You read a book.'},
#  {'translation_text': 'I took notes.'},
#  {'translation_text': 'You work out like this.'},
#  {'translation_text': 'All of you.'},
#  {'translation_text': 'So what?'},
#  {'translation_text': 'Breathe in.'},
#  {'translation_text': "I can't breathe."},
#  {'translation_text': "I'm most worried about this guy."},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': "I'm so scared of his book."},
#  {'translation_text': 'Oh, my God.'},
#  {'translation_text': 'Supported by'},
#  {'translation_text': "Ma'am, everyone says hello to Gott."},
#  {'translation_text': 'Hello. Hello.'},
#  {'translation_text': "Ma'am, you've seen a lot of teams today."},
#  {'translation_text': "Um, I don't know if you have anything in common today."},
#  {'translation_text': "That's it, that's it, that's it."},
#  {'translation_text': "It's called Gayla, isn't it?"},
#  {'translation_text': "Now we're Gayla."},
#  {'translation_text': 'Trying to be social.'},
#  {'translation_text': "Gla's the other guy."},
#  {'translation_text': "Today, you're asking us to go out with you."},
#  {'translation_text': "Gaya's team is together."},
#  {'translation_text': "Then we'll go together."},
#  {'translation_text': 'Not this scratch.'},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': "Hello, sir. It's Whit."},
#  {'translation_text': "Let's keep an eye on the subject right now."},
#  {'translation_text': 'Part of it.'},
#  {'translation_text': 'And look at the whole picture, sir.'},
#  {'translation_text': "I'm Arm."},
#  {'translation_text': 'Now.'},
#  {'translation_text': "Gayla's media team."},
#  {'translation_text': "It's too short. (Laughter)"},
#  {'translation_text': "Captain's name."},
#  {'translation_text': "It's Gayla's team."},
#  {'translation_text': 'Create a Web site'},
#  {'translation_text': 'And analyze the data a little bit.'},
#  {'translation_text': "Name's, uh..."},
#  {'translation_text': 'Now continue.'},
#  {'translation_text': 'Team Gala.'},
#  {'translation_text': 'Rain has come in for an internship at Gaya.'},
#  {'translation_text': 'In the lot.'},
#  {'translation_text': "Let's get this interview down to speed."},
#  {'translation_text': "When you guys leave, he'll take you with him."},
#  {'translation_text': "What I'm asking here is:"},
#  {'translation_text': 'I got an idea.'},
#  {'translation_text': "Let's try out some ideas."},
#  {'translation_text': "It's been months."},
#  {'translation_text': 'About'},
#  {'translation_text': "We're in a time of urgency."},
#  {'translation_text': 'We need to get up to work.'},
#  {'translation_text': "That's what I'm doing back there."},
#  {'translation_text': "It's a lot of work."},
#  {'translation_text': "Sometimes we're just doing our job."},
#  {'translation_text': 'I forgot about the development.'},
#  {'translation_text': 'I wish we could.'},
#  {'translation_text': 'Work, work, work, work, work.'},
#  {'translation_text': "Ask, when's the last time you worked out?"},
#  {'translation_text': 'When was the last time you calmed down?'},
#  {'translation_text': 'Reading.'},
#  {'translation_text': 'When was the last time you added a brain?'},
#  {'translation_text': 'When was the last time you recorded your experience?'},
#  {'translation_text': "We're going to be the ones who feel like running."},
#  {'translation_text': 'The exercise that we need is a lot of energy.'},
#  {'translation_text': "We feel like we're tired."},
#  {'translation_text': 'If you ask me if I work out a lot,'},
#  {'translation_text': "Not often, but it's a stretch."},
#  {'translation_text': "It's raining. It doesn't take very much notes."},
#  {'translation_text': "I'm asking if you like it."},
#  {'translation_text': 'Yeah.'},
#  {'translation_text': 'Every time we get back to writing.'},
#  {'translation_text': 'Talked to myself, kept a diary.'},
#  {'translation_text': 'Or do you think about it every day?'},
#  {'translation_text': "But it's like..."},
#  {'translation_text': "We can't be consistent."},
#  {'translation_text': 'So it turns out,'},
#  {'translation_text': 'Not much to write.'},
#  {'translation_text': 'Captain likes to read.'},
#  {'translation_text': 'But not for long.'},
#  {'translation_text': "Because there's a phone."},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': 'Draw attention.'},
#  {'translation_text': "What's that?"},
#  {'translation_text': "It's time."},
#  {'translation_text': 'To make our lives more valuable.'},
#  {'translation_text': 'What do you got?'},
#  {'translation_text': "One, it's a matter of the mind."},
#  {'translation_text': "There's a body problem."},
#  {'translation_text': "It's a matter of knowledge."},
#  {'translation_text': "And then there's the memory."},
#  {'translation_text': 'Mind is meditation.'},
#  {'translation_text': 'Focus.'},
#  {'translation_text': "As long as everyone's breathing."},
#  {'translation_text': 'You can all get your mind back on it.'},
#  {'translation_text': "I'm asking you why you're so focused."},
#  {'translation_text': "So that's it."},
#  {'translation_text': 'To see your own thoughts.'},
#  {'translation_text': 'My question is:'},
#  {'translation_text': "Who's got a hand?"},
#  {'translation_text': 'If you raise your hand.'},
#  {'translation_text': 'Is there anyone here?'},
#  {'translation_text': 'Being distracted makes you tense.'},
#  {'translation_text': 'Uh, okay, now.'},
#  {'translation_text': "Who's there?"},
#  {'translation_text': 'Who knows how to deal with their own distraction.'},
#  {'translation_text': 'Aah!'},
#  {'translation_text': 'Rain. Sometimes.'},
#  {'translation_text': 'Sometimes.'},
#  {'translation_text': "Who's here?"},
#  {'translation_text': 'Who knows how to deal with constant distraction.'},
#  {'translation_text': "Rain, I know, but I don't do it all the time."},
#  {'translation_text': 'Yeah, yeah.'},
#  {'translation_text': "Rain, maybe you don't even know."},
#  {'translation_text': 'So at least we realize'},
#  {'translation_text': 'Well, we are.'},
#  {'translation_text': 'Was distracted.'},
#  {'translation_text': 'Put yourself in a state of stress.'},
#  {'translation_text': "It's packed."},
#  {'translation_text': 'It needs to be released.'},
#  {'translation_text': 'And then when we let it go,'},
#  {'translation_text': 'Who was it?'},
#  {'translation_text': 'People in front of us.'},
#  {'translation_text': 'Everyone who came near us got hit.'},
#  {'translation_text': "So if we don't know how to stay calm,"},
#  {'translation_text': 'From the distraction.'},
#  {'translation_text': "He won't let go. He won't let go."},
#  {'translation_text': 'And I said,'},
#  {'translation_text': 'Is that out of the process?'},
#  {'translation_text': 'Get out.'},
#  {'translation_text': "How'd it get out?"},
#  {'translation_text': 'Wake up.'},
#  {'translation_text': 'How do you feel?'},
#  {'translation_text': 'Well, here it is.'},
#  {'translation_text': 'Back to your breath.'},
#  {'translation_text': 'When we come back to our senses,'},
#  {'translation_text': 'Or do you feel in our wind?'},
#  {'translation_text': "We'll find out."},
#  {'translation_text': 'The idea stopped working.'},
#  {'translation_text': 'And because we practice it a lot.'},
#  {'translation_text': "Working on it a lot, we'll find out."},
#  {'translation_text': "It's breathing."},
#  {'translation_text': 'Oh, this breath.'},
#  {'translation_text': "Hey, I'm having this idea right now."},
#  {'translation_text': "And they're not going to send it out to anyone else."},
#  {'translation_text': "It'll come back to itself."},
#  {'translation_text': 'No effort.'},
#  {'translation_text': 'To change my mind, too.'},
#  {'translation_text': 'But watch it.'},
#  {'translation_text': "Let's see where it goes."},
#  {'translation_text': 'Music'},
#  {'translation_text': "Where's it going?"},
#  {'translation_text': "And then we'll finally see the nature of it."},
#  {'translation_text': "It didn't last long."},
#  {'translation_text': "It'll be over in a minute."},
#  {'translation_text': 'This is a matter of mental importance.'},
#  {'translation_text': 'Physically.'},
#  {'translation_text': 'Our bodies are full of organs.'},
#  {'translation_text': 'We have an N.'},
#  {'translation_text': 'We have bones.'},
#  {'translation_text': 'We have muscle.'},
#  {'translation_text': 'We have a lot of organs.'},
#  {'translation_text': 'Everything.'},
#  {'translation_text': 'The question is:'},
#  {'translation_text': 'Do you need maintenance?'},
#  {'translation_text': 'Did you lose it every day?'},
#  {'translation_text': "So, here's the deal."},
#  {'translation_text': 'We also need to focus on the body.'},
#  {'translation_text': 'A lot of people work a lot.'},
#  {'translation_text': 'And then spend the money in the hospital.'},
#  {'translation_text': 'Because I forgot to look the other way.'},
#  {'translation_text': "Oh, really healthy. It's..."},
#  {'translation_text': 'A great fortune.'},
#  {'translation_text': 'Then we should know how to handle our bodies.'},
#  {'translation_text': "Next, it's the brain."},
#  {'translation_text': "It's the brain. It's important."},
#  {'translation_text': "It's a matter of thought."},
#  {'translation_text': 'To think about it, you need to have knowledge as a basis.'},
#  {'translation_text': "I can't figure it out because..."},
#  {'translation_text': "There's no knowledge."},
#  {'translation_text': 'Or just a few angles.'},
#  {'translation_text': "I haven't figured it out yet."},
#  {'translation_text': "If there's a problem, it's at this level."},
#  {'translation_text': 'And our knowledge is at this level.'},
#  {'translation_text': "We can't fix this."},
#  {'translation_text': 'But if the problem is at this level,'},
#  {'translation_text': "And then we're adding more and more information."},
#  {'translation_text': 'In the end, we can ignore the problem.'},
#  {'translation_text': 'That knowledge is a base.'},
#  {'translation_text': 'Reading, listening is important.'},
#  {'translation_text': "And then there's the memory."},
#  {'translation_text': 'Yes, we have knowledge.'},
#  {'translation_text': "I'm listening."},
#  {'translation_text': 'And already learned.'},
#  {'translation_text': "But I don't remember."},
#  {'translation_text': "Whit, I'm good at forgetting."},
#  {'translation_text': "And what's the use of that? (Laughter)"},
#  {'translation_text': "In the end, it didn't get any good."},
#  {'translation_text': "From the knowledge that you've wasted so much time reading."},
#  {'translation_text': "So I'm thinking four things."},
#  {'translation_text': 'Is to concentrate.'},
#  {'translation_text': 'Stand up. Stand up.'},
#  {'translation_text': 'Reading.'},
#  {'translation_text': 'Take notes.'},
#  {'translation_text': "I don't know what you're talking about."},
#  {'translation_text': '15 minutes at a time.'},
#  {'translation_text': "But let's keep going every day."},
#  {'translation_text': 'Which is my challenge for everyone.'},
#  {'translation_text': 'After today,'},
#  {'translation_text': 'Seven days.'},
#  {'translation_text': 'Seven days.'},
#  {'translation_text': "- Where's the camera? - Uh, okay."},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': "We'll interview you later."},
#  {'translation_text': "That after seven days, there's enough to stick together."},
#  {'translation_text': 'What do his sisters get for themselves?'},
#  {'translation_text': "So it's a bit of a continuous process."},
#  {'translation_text': "-Wick. -Oh, for me, there's a lot of pressure."},
#  {'translation_text': 'Because it has to be at least seven days.'},
#  {'translation_text': 'To complete the routine.'},
#  {'translation_text': 'This has, uh, in mind,'},
#  {'translation_text': "Hey, we'll have some free time."},
#  {'translation_text': 'To do something routine.'},
#  {'translation_text': "Is that what he's scheduled for?"},
#  {'translation_text': "Captain, I don't think it's gonna be okay."},
#  {'translation_text': 'It could be short on the third day.'},
#  {'translation_text': '4th, 5th, 6th.'},
#  {'translation_text': "Well, it's called four things, right?"},
#  {'translation_text': "Maybe there's something I didn't do."},
#  {'translation_text': 'Swindling, laughing.'},
#  {'translation_text': "Rain, if we're really busy, it's like an excuse."},
#  {'translation_text': "Well, I can't do it for seven days."},
#  {'translation_text': 'Just in case, you know what?'},
#  {'translation_text': "Arm, we've been so busy."},
#  {'translation_text': "We don't have much time."},
#  {'translation_text': 'And then to add a table to something.'},
#  {'translation_text': 'Come into our lives again.'},
#  {'translation_text': "It's kind of like..."},
#  {'translation_text': "It's hard enough, too."},
#  {'translation_text': "I'm not sure I'll get it."},
#  {'translation_text': "Let's start with meditation."},
#  {'translation_text': 'Now when we meditate,'},
#  {'translation_text': 'We will.'},
#  {'translation_text': 'Stay focused on the area.'},
#  {'translation_text': 'Right under your nose above your upper lip.'},
#  {'translation_text': "Because there's always going to be wind in and out of this area."},
#  {'translation_text': "It's just..."},
#  {'translation_text': 'We breathe unawares.'},
#  {'translation_text': "Let's just let it go automatically."},
#  {'translation_text': "We'll only know if we know."},
#  {'translation_text': "We're breathing hard, aren't we? It's breathing."},
#  {'translation_text': "That's why we feel the wind coming in."},
#  {'translation_text': 'And the wind comes out.'},
#  {'translation_text': 'How is that?'},
#  {'translation_text': "I'd like to invite everyone to try."},
#  {'translation_text': 'Try and focus on the area.'},
#  {'translation_text': 'As much as possible.'},
#  {'translation_text': "And then we'll find it's not easy."},
#  {'translation_text': 'To do.'},
#  {'translation_text': 'He thinks things. He thinks things.'},
#  {'translation_text': 'But whatever you think.'},
#  {'translation_text': "Don't follow his ideas."},
#  {'translation_text': "Don't worry about yourself."},
#  {'translation_text': "Oh, my God, what's wrong with you?"},
#  {'translation_text': 'No, no, no. Let it go. Let it go back to the wind.'},
#  {'translation_text': "You know you're coming back."},
#  {'translation_text': "It's like an idea that's going to keep going."},
#  {'translation_text': 'Pow, come back.'},
#  {'translation_text': 'Come back.'},
#  {'translation_text': 'And watch your breath.'},
#  {'translation_text': "It's as natural as it is."},
#  {'translation_text': "If it's going to take a short breath, let it breathe too short."},
#  {'translation_text': "If it's going to take a long breath, let it take a long breath."},
#  {'translation_text': 'Okay.'},
#  {'translation_text': 'Got it.'},
#  {'translation_text': 'Shall we?'},
#  {'translation_text': 'Come on.'},
#  {'translation_text': 'Music'},
#  {'translation_text': "How'd it go? 15 minutes ago."},
#  {'translation_text': 'Share your experience.'},
#  {'translation_text': 'What does that mean?'},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': 'Oh, shit.'},
#  {'translation_text': "It's crazy, isn't it? It's crazy, isn't it?"},
#  {'translation_text': 'Are you out of your mind?'},
#  {'translation_text': "Captain, let's go."},
#  {'translation_text': 'Are you out of your mind?'},
#  {'translation_text': "Whit, you're up."},
#  {'translation_text': 'Are you out of your mind? Rain.'},
#  {'translation_text': "This one's not the best help, it's the best."},
#  {'translation_text': 'Uh-oh-oh. Like, uh-huh.'},
#  {'translation_text': 'All the music, all the work, all the ideas.'},
#  {'translation_text': "I mean, it's a lot."},
#  {'translation_text': 'And then it turns out,'},
#  {'translation_text': "I can't concentrate."},
#  {'translation_text': "And it's just a matter of time."},
#  {'translation_text': 'I want to open my eyes and write down my ideas.'},
#  {'translation_text': 'Or, like, when is it going to be 15 minutes?'},
#  {'translation_text': 'What the hell?'},
#  {'translation_text': "Rain. We feel we're still distracted."},
#  {'translation_text': 'And also...'},
#  {'translation_text': 'It feels like time is running too slow.'},
#  {'translation_text': "Mm-hmm. When's 15 minutes?"},
#  {'translation_text': "Hey, look, there's something on our heads."},
#  {'translation_text': "It's a story. It's a story."},
#  {'translation_text': 'And we will.'},
#  {'translation_text': 'Back to your breath?'},
#  {'translation_text': "It's always going to fall off. It's like this."},
#  {'translation_text': "And then it's back to focus. It's not very good."},
#  {'translation_text': "And we're out of control, and we're out of control."},
#  {'translation_text': "And we're like,"},
#  {'translation_text': 'Afraid, uh...'},
#  {'translation_text': 'Are we going to hang up or not?'},
#  {'translation_text': "While I'm sitting."},
#  {'translation_text': 'This is it. This is the problem.'},
#  {'translation_text': "We're using a mind that's distracted."},
#  {'translation_text': 'Living every day.'},
#  {'translation_text': "And we can't handle the inside."},
#  {'translation_text': "We've become less focused on ourselves."},
#  {'translation_text': "But that's how you practice it."},
#  {'translation_text': 'Just a little bit a day. A little bit a day. A little bit a day.'},
#  {'translation_text': "It's gonna be like driving a car."},
#  {'translation_text': "We'll finally be able to drive."},
#  {'translation_text': "We'll know which rhythm to break."},
#  {'translation_text': 'Which should be a turner.'},
#  {'translation_text': 'Let go, let go'},
#  {'translation_text': "But if we don't know anything about this,"},
#  {'translation_text': "In the end, we're gonna become people."},
#  {'translation_text': "All I know is what's out there."},
#  {'translation_text': "But I don't know how to stop a mind that's distracted."},
#  {'translation_text': 'Because of this distraction.'},
#  {'translation_text': 'It makes people.'},
#  {'translation_text': 'Not happy at all.'},
#  {'translation_text': 'Sleep.'},
#  {'translation_text': "I couldn't sleep."},
#  {'translation_text': 'Think, think, think, think.'},
#  {'translation_text': "I've been thinking."},
#  {'translation_text': "I don't know what to stop thinking."},
#  {'translation_text': 'Looks like someone turned the radio on.'},
#  {'translation_text': "I don't know how to close it."},
#  {'translation_text': 'I ended up sleeping with a lot of ideas.'},
#  {'translation_text': "I'm tired of waking up."},
#  {'translation_text': 'No strength.'},
#  {'translation_text': 'Why is it that the mind never gets a rest?'},
#  {'translation_text': 'Rest of your body.'},
#  {'translation_text': "But my mind's tense."},
#  {'translation_text': 'Here.'},
#  {'translation_text': 'Can anyone come back to their senses?'},
#  {'translation_text': '-Wish. -All right.'},
#  {'translation_text': 'A little.'},
#  {'translation_text': "What's up?"},
#  {'translation_text': 'Hey, I got it.'},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': "That's good, that's good, that's good, that's good."},
#  {'translation_text': 'What about us?'},
#  {'translation_text': "It's almost as good as my brother's."},
#  {'translation_text': 'Yeah, a little bit, right?'},
#  {'translation_text': "It's okay. It's okay. It's okay."},
#  {'translation_text': "It's like us."},
#  {'translation_text': "I'm going to the grass in front of the house."},
#  {'translation_text': 'On the way.'},
#  {'translation_text': 'I saw your shirt.'},
#  {'translation_text': "I'll grab my shirt and wash it."},
#  {'translation_text': 'Between the hallways to the wash.'},
#  {'translation_text': "Seeing the dishes haven't been washed, we'll do the dishes."},
#  {'translation_text': 'I can finish the dishes.'},
#  {'translation_text': "It's a call."},
#  {'translation_text': 'I saw this. I saw this right there.'},
#  {'translation_text': 'Finally, continuous.'},
#  {'translation_text': 'This is our idea.'},
#  {'translation_text': "I don't think I'm done with one thing."},
#  {'translation_text': 'So the tool to stop it is'},
#  {'translation_text': 'Breathe.'},
#  {'translation_text': 'A lot of practice.'},
#  {'translation_text': "Well, now that you've gone,"},
#  {'translation_text': '15 minutes a day.'},
#  {'translation_text': 'I believe it was 15 minutes ago.'},
#  {'translation_text': "That's what everyone thought."},
#  {'translation_text': 'When are you going to be 15 minutes?'},
#  {'translation_text': 'What took you so long?'},
#  {'translation_text': "There's a lot of stuff there, right?"},
#  {'translation_text': 'There it is.'},
#  {'translation_text': "We're seeing that."},
#  {'translation_text': 'When we want something to happen,'},
#  {'translation_text': "And it's not what we want."},
#  {'translation_text': "It's a hell of a pain."},
#  {'translation_text': "It's so painful."},
#  {'translation_text': "And then we'll learn our nature."},
#  {'translation_text': 'Well, the torture happened.'},
#  {'translation_text': 'From our cravings.'},
#  {'translation_text': 'Because I want it to run out of time.'},
#  {'translation_text': 'Because I want it to be faster.'},
#  {'translation_text': "But time doesn't move any faster."},
#  {'translation_text': 'So I was miserable.'},
#  {'translation_text': "Let's share it. 15 minutes. How was your day?"},
#  {'translation_text': "My switch? That's what I'm talking about."},
#  {'translation_text': 'At first, I was thinking about it.'},
#  {'translation_text': "We're trying to hit it. We're trying to hit it."},
#  {'translation_text': 'Keep our breaths here.'},
#  {'translation_text': 'We need to focus here.'},
#  {'translation_text': 'We tried.'},
#  {'translation_text': 'Hmm. Focus.'},
#  {'translation_text': "Like, you're always here."},
#  {'translation_text': "I'll think about it soon enough."},
#  {'translation_text': 'Ah, go live with the water.'},
#  {'translation_text': 'I heard water.'},
#  {'translation_text': 'We circle back.'},
#  {'translation_text': 'Try to get your focus back.'},
#  {'translation_text': "But at least it's good that we..."},
#  {'translation_text': 'We know the point.'},
#  {'translation_text': 'Well, where should I come back?'},
#  {'translation_text': "Uh, when's Whitman supposed to be back?"},
#  {'translation_text': "That's right. It's his."},
#  {'translation_text': 'At least we know that.'},
#  {'translation_text': 'What point does it have to go back to?'},
#  {'translation_text': 'This is his.'},
#  {'translation_text': "Whit, you're trying to give us this."},
#  {'translation_text': 'Stay focused.'},
#  {'translation_text': 'The end of your nose is much more self-centered.'},
#  {'translation_text': 'So what kind of activity do we do?'},
#  {'translation_text': 'Trying to get us back on our own.'},
#  {'translation_text': 'A lot of times.'},
#  {'translation_text': 'We feel...'},
#  {'translation_text': "Hey, we're flowing."},
#  {'translation_text': 'To live in a social setting, or...'},
#  {'translation_text': 'People meet in our everyday lives again.'},
#  {'translation_text': "We're going to focus on ourselves."},
#  {'translation_text': "It's quite small."},
#  {'translation_text': 'But when I went with Gottp,'},
#  {'translation_text': 'Gott makes us feel'},
#  {'translation_text': 'We can come back to ourselves more easily.'},
#  {'translation_text': "That's all, sir."},
#  {'translation_text': 'And use it all day long.'},
#  {'translation_text': 'Before we start.'},
#  {'translation_text': 'Before work.'},
#  {'translation_text': 'Before I focus on anything,'},
#  {'translation_text': 'One minute.'},
#  {'translation_text': 'Come back to your breath.'},
#  {'translation_text': 'And take the power of focus for a second.'},
#  {'translation_text': "Let's get back to work."},
#  {'translation_text': "Get in there. There's a problem."},
#  {'translation_text': 'Oh, my God. I got hit by a guy over there.'},
#  {'translation_text': "Shut down the comms. We'll be gone in a minute."},
#  {'translation_text': 'To the park.'},
#  {'translation_text': 'You can do it with your eyes open.'},
#  {'translation_text': 'Come back to your breath.'},
#  {'translation_text': "When we're thinking about subtracting."},
#  {'translation_text': 'Our breaths will change.'},
#  {'translation_text': "It's not light, it's sick."},
#  {'translation_text': "I can't even hold the wind."},
#  {'translation_text': 'Any part of the body is tense.'},
#  {'translation_text': 'Such as?'},
#  {'translation_text': "It'll take me a while to figure it out."},
#  {'translation_text': 'Let go!'},
#  {'translation_text': 'Let go!'},
#  {'translation_text': "There's gonna be some tension."},
#  {'translation_text': "That's why we're so slow."},
#  {'translation_text': 'Found the natural truth:'},
#  {'translation_text': 'How are mental stress affecting the body?'},
#  {'translation_text': 'So we can see that back in the wind.'},
#  {'translation_text': 'Hey, guys, breathe like this.'},
#  {'translation_text': "Which means what we're thinking is going to happen."},
#  {'translation_text': "There's a process coming back to check it out."},
#  {'translation_text': "How's it going?"},
#  {'translation_text': "Captain, it's going to raise its voice in the past."},
#  {'translation_text': "It's like there's a sound coming in."},
#  {'translation_text': "That's a little bit of luck. That's a guy's voice."},
#  {'translation_text': 'What he said, it came back.'},
#  {'translation_text': 'We get confused, and then...'},
#  {'translation_text': 'Back to your breath.'},
#  {'translation_text': 'And a little sneer.'},
#  {'translation_text': 'When we got back to the wind,'},
#  {'translation_text': "Hey, it doesn't hurt. We don't get to focus there."},
#  {'translation_text': "You can't sit when you're normal."},
#  {'translation_text': "There's a little bit of sarcasm."},
#  {'translation_text': 'With so much energy, so much sleep.'},
#  {'translation_text': 'It makes us a lot easier.'},
#  {'translation_text': 'Calm down.'},
#  {'translation_text': "I know it's not sleeping."},
#  {'translation_text': "I didn't know it was the light on my face."},
#  {'translation_text': 'Or what?'},
#  {'translation_text': "It's more breathing."},
#  {'translation_text': 'It feels like an experience.'},
#  {'translation_text': "Better than when you're sitting on your own."},
#  {'translation_text': 'Yes.'},
#  {'translation_text': "Actually, it's almost everyone's problem."},
#  {'translation_text': "We've been pushed by our past thoughts to make us miserable."},
#  {'translation_text': "Despite what it's been through,"},
#  {'translation_text': "But we can't put the thought down."},
#  {'translation_text': "Because we don't know how to focus."},
#  {'translation_text': 'With current moment'},
#  {'translation_text': 'The breath is the present moment.'},
#  {'translation_text': "When we don't find a way to focus on the current breath,"},
#  {'translation_text': "What's the follow-up?"},
#  {'translation_text': 'We get pulled over by the past.'},
#  {'translation_text': "It's been 10 years."},
#  {'translation_text': "Some people can't let go."},
#  {'translation_text': 'Oh, come on.'},
#  {'translation_text': "I won't let you in next life."},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': "Someone's got it that way."},
#  {'translation_text': 'But if people get this,'},
#  {'translation_text': "I'll be sure to know."},
#  {'translation_text': "Oh, we're running after what's already dead."},
#  {'translation_text': 'In the meantime,'},
#  {'translation_text': 'Some suffer from an unborn future.'},
#  {'translation_text': "Whether you're miserable in the past or in the future that hasn't happened."},
#  {'translation_text': 'It can go back from this cycle.'},
#  {'translation_text': 'By going back.'},
#  {'translation_text': 'This is the present.'},
#  {'translation_text': 'We have legs. We have legs.'},
#  {'translation_text': 'We were taken by the thought of the past.'},
#  {'translation_text': "- Give us don't like it. - Don't like it."},
#  {'translation_text': "But in the end, when we're back in the present,"},
#  {'translation_text': "We'll find out there's nothing in the present."},
#  {'translation_text': "We've already been through that."},
#  {'translation_text': "It's easy to teach. It's easy."},
#  {'translation_text': 'little by little, little by little.'},
#  {'translation_text': 'Oh, my God, you were like this before.'},
#  {'translation_text': "He's got a body in him."},
#  {'translation_text': "Oh, my God, that's what I said."},
#  {'translation_text': 'Hmm.'},
#  {'translation_text': 'When I see him,'},
#  {'translation_text': 'Still carrying that thought.'},
#  {'translation_text': "Doesn't look at him with the eyes of the present."},
#  {'translation_text': 'We change every day.'},
#  {'translation_text': "Why can't someone who does something bad to us change?"},
#  {'translation_text': "But we're not used to being present."},
#  {'translation_text': 'So we judge him with a picture of the past.'},
#  {'translation_text': 'At the same time, some of us like it a lot.'},
#  {'translation_text': "Oh, this one's good. It's good. It's good."},
#  {'translation_text': "Maybe they're bad these days."},
#  {'translation_text': "We're still changing."},
#  {'translation_text': "That's why we need to train ourselves."},
#  {'translation_text': 'Back to the present.'},
#  {'translation_text': 'So we can see each other.'},
#  {'translation_text': 'In fact, in the present, it really is.'},
#  {'translation_text': "How's it going?"},
#  {'translation_text': "Hey, I've seen a movie."},
#  {'translation_text': "And what's the movie we're looking at? It's imaginary."},
#  {'translation_text': "That's a good point. Keep going."},
#  {'translation_text': 'Hey, and we can imagine the movie we saw.'},
#  {'translation_text': "It's like this. It's like this."},
#  {'translation_text': "And then we're back to focus."},
#  {'translation_text': "And he's out."},
#  {'translation_text': "I feel like I'm on a movie show."},
#  {'translation_text': 'The movie we watched, it came in.'},
#  {'translation_text': "That's a good point."},
#  {'translation_text': "That's where we see it."},
#  {'translation_text': 'How do our addictions affect our minds?'},
#  {'translation_text': 'And the good thing is,'},
#  {'translation_text': "Once we've imagined and we've come to our senses,"},
#  {'translation_text': 'I told you.'},
#  {'translation_text': 'Even the people around me or the people from far away said,'},
#  {'translation_text': 'Picking a drug.'},
#  {'translation_text': 'What are you looking at? What are you listening to?'},
#  {'translation_text': 'Filters'},
#  {'translation_text': 'Because it does.'},
#  {'translation_text': 'So much for our thinking system.'},
#  {'translation_text': "Once we're back in the game, we'll focus on the present."},
#  {'translation_text': "In the end, what we're using won't get in."},
#  {'translation_text': "It's coming in."},
#  {'translation_text': 'Pull us out of the present moment to imagine.'},
#  {'translation_text': "See, what we're really into is a lot of stuff."},
#  {'translation_text': 'To life.'},
#  {'translation_text': "Whether it's food."},
#  {'translation_text': "It's all about the text."},
#  {'translation_text': "Whether it's about the video,"},
#  {'translation_text': 'Whatever.'},
#  {'translation_text': 'Yeah. How many?'},
#  {'translation_text': "It'll only find a way out."},
#  {'translation_text': "But that's exactly what day it's gonna come out of."},
#  {'translation_text': "That's it."},
#  {'translation_text': 'Good.'},
#  {'translation_text': "How's it going?"},
#  {'translation_text': "It's raining, and..."},
#  {'translation_text': "Do you feel like, hey, why it's been over 15 minutes?"},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': 'And then I talked to him, like,'},
#  {'translation_text': 'The idea came through, but...'},
#  {'translation_text': "We know we're losing our minds."},
#  {'translation_text': 'But I wanted to talk to myself.'},
#  {'translation_text': "Let's talk. Okay, here's the thing."},
#  {'translation_text': "- When we're done, - Okay."},
#  {'translation_text': 'Come back for a fresh breath.'},
#  {'translation_text': "That's good, that's good, that's good."},
#  {'translation_text': 'What the hell is 15 minutes of this?'},
#  {'translation_text': "Actually, it's a pain."},
#  {'translation_text': "It's a grudge."},
#  {'translation_text': "It's hard to concentrate."},
#  {'translation_text': 'If we get too sleepy,'},
#  {'translation_text': 'Too distracted.'},
#  {'translation_text': "And you don't have to interpret that."},
#  {'translation_text': "I'm upset because I've been sitting here a long time."},
#  {'translation_text': 'Because time is too much.'},
#  {'translation_text': "I just know I'm upset."},
#  {'translation_text': 'And look at this frustration.'},
#  {'translation_text': 'How does that affect your breath?'},
#  {'translation_text': "That's all."},
#  {'translation_text': "You're coming back."},
#  {'translation_text': "Arm, it's really nice of us to make a decision."},
#  {'translation_text': 'To ask you something, Got.'},
#  {'translation_text': 'And he gave me the tools to say,'},
#  {'translation_text': 'That we are?'},
#  {'translation_text': 'Trying to stop the idea.'},
#  {'translation_text': 'More than observation.'},
#  {'translation_text': "What it's like."},
#  {'translation_text': 'Or where it took us.'},
#  {'translation_text': 'We feel like this device just made sense that day.'},
#  {'translation_text': "That's what it makes us feel like."},
#  {'translation_text': "Uh, today's coming."},
#  {'translation_text': 'It makes us complete.'},
#  {'translation_text': "And it's really a technique to go home."},
#  {'translation_text': "Okay, so here's the bottom line:"},
#  {'translation_text': 'Each one of them.'},
#  {'translation_text': "Just now, as far as I'm concerned."},
#  {'translation_text': 'Got one thing for sure.'},
#  {'translation_text': "It's about coming back to you."},
#  {'translation_text': 'And knowing'},
#  {'translation_text': "I'm working on it right now."},
#  {'translation_text': "That's exactly what this is."},
#  {'translation_text': "Most people think they don't know what they're thinking."},
#  {'translation_text': "Now we've got the secret."},
#  {'translation_text': "I know I'm thinking."},
#  {'translation_text': '15 minutes of practice every morning.'},
#  {'translation_text': 'Right away, wake up.'},
#  {'translation_text': "Let's concentrate."},
#  {'translation_text': "Don't touch the phone."},
#  {'translation_text': "Don't read yet."},
#  {'translation_text': "Don't do anything yet."},
#  {'translation_text': 'Wash your face, wash your eyes, call it freshness.'},
#  {'translation_text': '15 minutes in the morning.'},
#  {'translation_text': "It's breathing."},
#  {'translation_text': 'Focus on breathing in and out.'},
#  {'translation_text': "I can't wait to scrub my legs."},
#  {'translation_text': 'You can sit in a chair.'},
#  {'translation_text': 'Lie down and do this.'},
#  {'translation_text': 'Because if you do this,'},
#  {'translation_text': "I'll be late for work."},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': "It's gonna be a long time."},
#  {'translation_text': 'Oh, we forgot one thing.'},
#  {'translation_text': 'After every meditation,'},
#  {'translation_text': 'Best wishes.'},
#  {'translation_text': 'Create an atmosphere in our room.'},
#  {'translation_text': 'After we calm down,'},
#  {'translation_text': 'Send your best wishes.'},
#  {'translation_text': 'Thank you.'},
#  {'translation_text': "The work we've done."},
#  {'translation_text': 'A colleague who works with us.'},
#  {'translation_text': 'Four factors, anything that makes us comfortable.'},
#  {'translation_text': 'Every penny we have.'},
#  {'translation_text': 'Thank you.'},
#  {'translation_text': 'I appreciate it.'},
#  {'translation_text': 'And then as we keep doing this,'},
#  {'translation_text': "We'll find one chicken pan."},
#  {'translation_text': 'Thank you very much.'},
#  {'translation_text': 'Because our hearts are about to get more detailed.'},
#  {'translation_text': "We'll start seeing that."},
#  {'translation_text': "By the time the rice's in our dishes,"},
#  {'translation_text': 'How many times has it been?'},
#  {'translation_text': "There's a lot of places to go."},
#  {'translation_text': "Because we're more thorough."},
#  {'translation_text': 'So we can look at things a little bit more carefully.'},
#  {'translation_text': 'Thank you. Thank you. Thank you.'},
#  {'translation_text': "And we'll be happy with that."},
#  {'translation_text': "I'm asking you, maybe the first part doesn't work all the time."},
#  {'translation_text': 'But at least...'},
#  {'translation_text': '10 days, maybe one day.'},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': "That's it."},
#  {'translation_text': 'Rain. Thank you, Got. (Laughter)'},
#  {'translation_text': 'Thank you. Thank you.'},
#  {'translation_text': "We'll take care of it."},
#  {'translation_text': 'Easy before you go to work.'},
#  {'translation_text': '15 minutes.'},
#  {'translation_text': "Okay, let's get started."},
#  {'translation_text': 'Let me see this one.'},
#  {'translation_text': "I'm most worried about this guy."},
#  {'translation_text': 'Captain, why did he choose us?'},
#  {'translation_text': "We feel like, uh, we have a problem, don't we?"},
#  {'translation_text': "I'm almost sick of anything."},
#  {'translation_text': 'If we go to the park,'},
#  {'translation_text': "We'll be like..."},
#  {'translation_text': 'Ama.'},
#  {'translation_text': "He's very strong."},
#  {'translation_text': 'Mm-hmm.'},
#  {'translation_text': "That's why you have your own gym at home."},
#  {'translation_text': "Because you're playing outside."},
#  {'translation_text': "They say you're crazy."},
#  {'translation_text': '(Laughter)'},
#  {'translation_text': 'Music. The day I wake up.'},
#  {'translation_text': 'A song. A day to stand again.'},
#  {'translation_text': 'Music is enough to lose.'},
#  {'translation_text': 'Music is enough to let anyone'},
#  {'translation_text': 'Music, everything.'},
#  {'translation_text': 'Music'},
#  {'translation_text': 'The thick voice comes from both our friends and his friends.'},
#  {'translation_text': "That he's changed."},
#  {'translation_text': 'I mean, he likes guys.'},
#  {'translation_text': 'And think about who we like.'},
#  {'translation_text': 'Bring your face closer.'},
#  {'translation_text': "Everybody's been deaf."},
#  {'translation_text': "What's he saying? We're like this."},
#  {'translation_text': 'Hello. Welcome to the orange soft.'},
#  {'translation_text': "It's February. What's it like?"},
#  {'translation_text': "It'll be the day of the sacrifice."},
#  {'translation_text': "Valentine's Day."},
#  {'translation_text': "That's what love is all about."},
#  {'translation_text': 'So this is calculating.'},
#  {'translation_text': 'How many people in your head right now?'},
#  {'translation_text': "I'm trying to figure out who to tell the story."},
#  {'translation_text': 'We can have our first love many times.'},
#  {'translation_text': 'First love.'},
#  {'translation_text': "My heart's broken."},
#  {'translation_text': 'I know my age right away.'},
#  {'translation_text': "It's not love, everybody."},
#  {'translation_text': "But it's kind of a fuse."},
#  {'translation_text': 'It happened in a brand-new Chang in elementary school.'},
#  {'translation_text': 'I had a crush on one of my seniors.'},
#  {'translation_text': "Since he's in fifth grade, we're in fourth grade."},
#  {'translation_text': "You're so young. You're so young."},
#  {'translation_text': 'We remember that time was fourth grade.'},
#  {'translation_text': 'To be a cheerleader.'},
#  {'translation_text': "And we can't dance."},
#  {'translation_text': "And he's, like, a senior with the same color."},
#  {'translation_text': "And he's the one who taught us how to dance."},
#  {'translation_text': '5th graders'},
#  {'translation_text': "Yeah, I'm five years old. I'm a four-year-old."},
#  {'translation_text': '12123 12121'},
#  {'translation_text': "And we're just so grateful for the way things are."},
#  {'translation_text': "He's very interested in the way other brothers teach."},
#  {'translation_text': 'But this brother, like I taught him on purpose,'},
#  {'translation_text': "That's why it's so impressive that he cares about us."},
#  {'translation_text': 'And we secretly like him.'},
#  {'translation_text': "It's when we moved to all the girls' schools."},
#  {'translation_text': "Here's to middle school, where this is a high school."},
#  {'translation_text': "And in the past, we've never known each other."},
#  {'translation_text': 'With a creature called a man.'},
#  {'translation_text': 'Which is where we went to school.'},
#  {'translation_text': "It's a school of art."},
#  {'translation_text': "Is that there's a pattern."},
#  {'translation_text': 'The guy who majored in music, the music major, the guitar major.'},
#  {'translation_text': 'The guy with the guitar is a handsome guy.'},
#  {'translation_text': 'All right, everybody?'},
#  {'translation_text': "And we're really into the current."},
#  {'translation_text': 'And a lot of people like him.'},
#  {'translation_text': "Yeah, I'd love that."},
#  {'translation_text': "Because people like it so much, they'll like it."},
#  {'translation_text': 'A friend of the same class.'},
#  {'translation_text': "He's in seventh grade. He's still in the same school."},
#  {'translation_text': 'And then we go up 6th.'},
#  {'translation_text': 'And our friend, he knows we like it.'},
#  {'translation_text': 'Our friend took care of our phone.'},
#  {'translation_text': 'And text. Here.'},
#  {'translation_text': "It's a flirt."},
#  {'translation_text': "I'm not hitting on you. I'm not hitting on you."},
#  {'translation_text': "All I'm saying is, of course, we're going to have to break in because..."},
#  {'translation_text': "We're the little guys he's got. There's a whole school likes it."},
#  {'translation_text': "We're just this much and we're like,"},
#  {'translation_text': "I'll do whatever I can for this guy."},
#  {'translation_text': 'Look at this. What the hell?'},
#  {'translation_text': "And that's when we saw this little movie called Love."},
#  {'translation_text': 'Is that...'},
#  {'translation_text': "I'm the brother of Sean's water."},
#  {'translation_text': "It's in a little thing with the mammary polishing and the type."},
#  {'translation_text': 'The water is all for you.'},
#  {'translation_text': "It's Drummeyer for you to turn around."},
#  {'translation_text': 'This is it. This is it. This is it.'},
#  {'translation_text': 'Remember, my friend with the lyrics.'},
#  {'translation_text': "It's the song in the album."},
#  {'translation_text': 'You want to hear it?'},
#  {'translation_text': 'Her heart is calling for her.'},
#  {'translation_text': 'Something very long.'},
#  {'translation_text': 'And then he sent it back, so what the hell did he have to talk about?'},
#  {'translation_text': "And there's a chance we'll be together."},
#  {'translation_text': 'Well, that was my first boyfriend in the sixth grade.'},
#  {'translation_text': 'I remember we were trying to, like,'},
#  {'translation_text': "Put yourself where he's found."},
#  {'translation_text': "All of Thailand's high school kids have to go through this."},
#  {'translation_text': "The guy who likes it, he's gonna have a place in the cafeteria, right?"},
#  {'translation_text': "We're gonna have to walk through there a lot."},
#  {'translation_text': "Or maybe this is room one, right? And he's in room seven."},
#  {'translation_text': "We're gonna go to the bathroom."},
#  {'translation_text': 'One day, ten times in the bathroom.'},
#  {'translation_text': 'Walk by, walk by.'},
#  {'translation_text': 'Walk through it, walk through it, walk through it.'},
#  {'translation_text': 'Look at it with your heart.'},
#  {'translation_text': 'Let us feel that this is the drive to my school.'},
#  {'translation_text': "It's the same as this guy, people."},
#  {'translation_text': 'Keep trying to get in his way.'},
#  {'translation_text': "That's what makes him see us all the time."},
#  {'translation_text': 'This is what happened.'},
#  {'translation_text': 'I remember a scene he was walking by with a friend, and he was like,'},
#  {'translation_text': "It's like coming near us and saying something to us."},
#  {'translation_text': 'And think about who we like.'},
#  {'translation_text': 'Bring your face closer.'},
#  {'translation_text': "And I don't remember what he said, but I do."},
#  {'translation_text': 'The shot he took brought his face closer and closer.'},
#  {'translation_text': 'Like a fuse.'},
#  {'translation_text': "He's with a friend and he's just like us."},
#  {'translation_text': "And then you talk to us nearby, and it's like,"},
#  {'translation_text': "Everybody's been deaf."},
#  {'translation_text': "What's he saying? We're like this."},
#  {'translation_text': "What did he say? I didn't hear anything."},
#  {'translation_text': 'I mean, we look at his face and we feel like...'},
#  {'translation_text': 'Love. This is love.'},
#  {'translation_text': "Yeah, well, it's kind of embarrassing, everybody."},
#  {'translation_text': 'We felt it at the time.'},
#  {'translation_text': 'To get close to a man.'},
#  {'translation_text': 'Well, back then, it was just a guy with his hand on his shoulder.'},
#  {'translation_text': "I can't. I'll tell you to marry him."},
#  {'translation_text': "I said don't touch a man, okay?"},
#  {'translation_text': "But it's when they bring their faces closer to us."},
#  {'translation_text': "We feel like we're gonna walk into his hand and say we're a couple."},
#  {'translation_text': "But I couldn't, because I was still embarrassed and didn't have the courage."},
#  {'translation_text': 'Still want to be friends.'},
#  {'translation_text': "I don't know why, because he already knows we like him."},
#  {'translation_text': 'Leave it to the kids of this generation, if you like.'},
#  {'translation_text': "Don't play with me like that."},
#  {'translation_text': "It's good to be a friend."},
#  {'translation_text': 'No, I like it. Tell me you like it. Let him know.'},
#  {'translation_text': 'Well, at least let it be known that a life has to say what we think it is.'},
#  {'translation_text': 'How can you be so angry?'},
#  {'translation_text': 'We moved to Bangkok to sing, etc.'},
#  {'translation_text': "Life's too busy with the contest."},
#  {'translation_text': "Because it's on TV every week. It's practice dancing."},
#  {'translation_text': "It's supposed to be a duet. It's got to be a show."},
#  {'translation_text': "Turns out they're kind of separated."},
#  {'translation_text': 'And we heard a thick voice.'},
#  {'translation_text': 'Our friends and his friends.'},
#  {'translation_text': "That he's changed something."},
#  {'translation_text': "But he's changed in here, which means he likes men."},
#  {'translation_text': "That's what I'm saying."},
#  {'translation_text': "I mean, we're bad radar. We're still broken."},
#  {'translation_text': 'And I remember the four years we talked about.'},
#  {'translation_text': "That means we're dating."},
#  {'translation_text': "I've had this fight with my friends, and I've barely talked to my friends because"},
#  {'translation_text': "Dude, I'm trying to warn you."},
#  {'translation_text': "I've got a friend here to warn me."},
#  {'translation_text': 'My friends are trying to tell me that, you know,'},
#  {'translation_text': "I don't think so."},
#  {'translation_text': 'So this has to be said.'},
#  {'translation_text': "It's been a long time since we liked him since first grade."},
#  {'translation_text': 'And then, like, a lot of comics, a lot of movies, and we felt like,'},
#  {'translation_text': "A life. I'm gonna have to tell him I love him."},
#  {'translation_text': 'At least let him know'},
#  {'translation_text': 'Do you have him in your heart?'},
#  {'translation_text': 'So that day, I bought him some earpieces.'},
#  {'translation_text': 'And then I walked up.'},
#  {'translation_text': 'And then he handed it to him, and he said,'},
#  {'translation_text': 'I like you, and then I run out.'},
#  {'translation_text': "The speed at which it's very awkward."},
#  {'translation_text': "That's what happened. Didn't listen to what he said."},
#  {'translation_text': 'Not listening, not ready to listen.'},
#  {'translation_text': "I'm telling you, this is what you want."},
#  {'translation_text': "And here's the conclusion:"},
#  {'translation_text': "I'm not seeing him anymore."},
#  {'translation_text': "He's got someone he likes, too."},
#  {'translation_text': "So they're apart from each other."},
#  {'translation_text': "But there's a bit of a problem here."},
#  {'translation_text': 'On the day he left at third grade, right?'},
#  {'translation_text': "We're still in school, and when we get into high school,"},
#  {'translation_text': 'We had a chance to talk to him again on Facebook.'},
#  {'translation_text': "And he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's..."},
#  {'translation_text': "He's hitting on us."},
#  {'translation_text': "Turns out he's hitting on us now when we were in high school."},
#  {'translation_text': "Which is why we're happy. We're very happy."},
#  {'translation_text': 'But it turns out that we...'},
#  {'translation_text': "It's like we talked about it and it's like it's not a match."},
#  {'translation_text': "We haven't felt that."},
#  {'translation_text': 'What does a relationship have to do with a boyfriend?'},
#  {'translation_text': 'And then we went ahead and asked him what kind of person he was.'},
#  {'translation_text': 'Hey, can we just, like, clear this up?'},
#  {'translation_text': 'Whether or not it is.'},
#  {'translation_text': "But then he was on the phone, and he said he wasn't."},
#  {'translation_text': 'He likes girls.'},
#  {'translation_text': 'So we feel that if he says he likes women,'},
#  {'translation_text': "We're gonna have to trust our own people, you know?"},
#  {'translation_text': 'Finally, when we started hearing about what kind of man he liked,'},
#  {'translation_text': 'So we started looking into it.'},
#  {'translation_text': "There's a point where that range uses Hi5."},
#  {'translation_text': "- Hi, what's up? - Yeah."},
#  {'translation_text': 'We remember where important people will be.'},
#  {'translation_text': "If it's not the first one, it's the middle one."},
#  {'translation_text': 'Well, either the first or the middle.'},
#  {'translation_text': 'We were the first.'},
#  {'translation_text': 'What about when we went to the competition?'},
#  {'translation_text': "We've got a hip-five going around, don't we?"},
#  {'translation_text': 'And then we just noticed, uh, in the middle of it, it turns people.'},
#  {'translation_text': 'Suddenly, it turned into a junior.'},
#  {'translation_text': "This guy's got a clue."},
#  {'translation_text': "I mean, it's really cute and it's like, you know, it's like, you know, it's like, you know, it's like, you know, you know, you're like, you know, you're like, you know, you're like, you're like, you know, you're like, you're like, you know, you're like, you're like, you know, you're like, you're like, you're like, you're like, you're like, you're like, you're kind of, you know, like, you're kind of, like, kind of, like, kind of, like, you know, like, you know, you know, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, like, like, like, like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, like, you're like, like, like, like, you're like, you're like, you're like, like, like, like, like, like, you're like, you're like, you're like, you're like, you're like, like, you're like, like, like, like, like, like, like, like, like, like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, like, you're like, you're like, you're like, you're like, you're like, you're"},
#  {'translation_text': "It's a couple of levels of age apart."},
#  {'translation_text': 'How the hell did they get to know each other?'},
#  {'translation_text': 'Why is it in the middle of something?'},
#  {'translation_text': 'After the contest ended, we started looking into it.'},
#  {'translation_text': 'Start calling his friends.'},
#  {'translation_text': "Just to be honest, I'd like to be honest with you."},
#  {'translation_text': "What's going on while we're gone?"},
#  {'translation_text': 'So I finally realized, "Oh, okay."'},
#  {'translation_text': 'I mean, he should have a body that likes men.'},
#  {'translation_text': 'So we broke up with him.'},
#  {'translation_text': "And frankly, we didn't tell him why we broke up that day."},
#  {'translation_text': 'Oh, and, uh...'},
#  {'translation_text': 'We have a surprise today.'},
#  {'translation_text': "No, but it's been a long time."},
#  {'translation_text': "I'm still friends with him on Facebook these days."},
#  {'translation_text': "That's what it's like for our first love."},
#  {'translation_text': "What do you give? It's actually a lot of money."},
#  {'translation_text': "It's a good memory for us since we were kids."},
#  {'translation_text': "I mean, even if we like him, we're not dating him."},
#  {'translation_text': "But that's what got us all dressed up."},
#  {'translation_text': 'Get up and do it. Get up and take care of yourself.'},
#  {'translation_text': "It's an inspiration to go to school every day."},
#  {'translation_text': 'Yes.'},
#  {'translation_text': "It's kind of fun."},
#  {'translation_text': "I mean, if we don't have this one back,"},
#  {'translation_text': "I mean, we're gonna be living like, like,"},
#  {'translation_text': 'Study, study, study, study.'},
#  {'translation_text': 'What kind of study is this kid supposed to do?'},
#  {'translation_text': "But when he's got all the men, he's got the energy to keep his life active."},
#  {'translation_text': "Which I'm not saying everyone's like this, okay?"},
#  {'translation_text': "Some people learn one thing and they're happy, okay?"},
#  {'translation_text': 'Time will help us get to know ourselves.'},
#  {'translation_text': "The distance that's going on or anything, it just makes people kind of"},
#  {'translation_text': 'You can review and grow up and get to know yourself.'},
#  {'translation_text': 'Today he gets to know himself better.'},
#  {'translation_text': 'We all get to know ourselves a little bit better.'},
#  {'translation_text': "In the end, it's going to be a lesson for both of them."},
#  {'translation_text': "Once we have a new relationship, we'll have a new relationship."},
#  {'translation_text': "So we're going to kind of take lessons and kind of use them in a way."},
#  {'translation_text': 'What the hell does love continue to live for?'},
#  {'translation_text': "We believe everyone's sitting with their friends."},
#  {'translation_text': "It's about the past we've been sorry about."},
#  {'translation_text': 'What if we come back here and tell you the story?'},
#  {'translation_text': "It's going to be very funny."},
#  {'translation_text': "And we're gonna laugh at our friends about why I'm doing this."},
#  {'translation_text': 'What have you done?'},
#  {'translation_text': "That's how everyone remembers."},
#  {'translation_text': 'And it makes us beautiful to this day.'},
#  {'translation_text': "You've got a face. You've got a curse on you."},
#  {'translation_text': "I said I was too tough. I'm sorry."},
#  {'translation_text': "At first we didn't have the guts to tell them because they were so young, people would be like,"},
#  {'translation_text': "She's been a slut since 12."},
#  {'translation_text': "What the hell? It's so young."},
#  {'translation_text': 'But we only love you, Odd.'},
#  {'translation_text': 'This is one more time for the PreviewPoP.'},
#  {'translation_text': "I didn't come to sign."},
#  {'translation_text': "Because we're talking about a murder."},
#  {'translation_text': 'Hello, doctor. Hello, Pop.'},
#  {'translation_text': "I didn't come to sign the papers. I'm serious."},
#  {'translation_text': "Because I didn't come. I mean, I did."},
#  {'translation_text': "Let's try it."},
#  {'translation_text': '- How to murder someone? - Yes.'},
#  {'translation_text': "We're just talking about examples of what's happened in the world, sir."},
#  {'translation_text': 'But first, I need to get to know the money doctor.'},
#  {'translation_text': "You're a real doctor, aren't you?"},
#  {'translation_text': "He's a real doctor."},
#  {'translation_text': "It's when you graduate from med school."},
#  {'translation_text': 'And go to medical school to slow your age.'},
#  {'translation_text': 'Sexual and clinical medicine.'},
#  {'translation_text': "I'm just interested in crime."},
#  {'translation_text': "If you're not mistaken, it's med school."},
#  {'translation_text': 'What kind of stuff?'},
#  {'translation_text': '- A few of them. - Yes, sir.'},
#  {'translation_text': 'Because when we went to med school, we took a lot of classes.'},
#  {'translation_text': 'Many branches like this, sir.'},
#  {'translation_text': "It's the principal's surgery."},
#  {'translation_text': "Or in high school, there's going to be a separate course."},
#  {'translation_text': "It's forensics."},
#  {'translation_text': "That's about the autopsy."},
#  {'translation_text': 'Or, hey, look at all this criminal evidence.'},
#  {'translation_text': 'But according to your studies, medicine slows you down.'},
#  {'translation_text': "- with the murders, it's pretty isolated. - Yeah."},
#  {'translation_text': "- Actually, the doctor's check, right? - Yeah."},
#  {'translation_text': "Now we're going to use the capital."},
#  {'translation_text': "I have an experience with the M.E.'s office."},
#  {'translation_text': 'And finally, right then.'},
#  {'translation_text': "We're going to study in the field we're interested in."},
#  {'translation_text': "It's about beauty. It's about aging."},
#  {'translation_text': 'But on the other side of our lives.'},
#  {'translation_text': 'Are we the ones who are interested or the ones who are attracted to us?'},
#  {'translation_text': '- The story of the investigation. - Oh.'},
#  {'translation_text': "That's why I'm interested in that, too."},
#  {'translation_text': "But I didn't go to any forensics class. Mm."},
#  {'translation_text': "It's just a partial feeling. We're interested."},
#  {'translation_text': "And I'd like to learn something like that."},
#  {'translation_text': "So it's like two sides."},
#  {'translation_text': "I understand that if we're interested in the investigation,"},
#  {'translation_text': "What's wrong with being there, M.E.?"},
#  {'translation_text': 'Or forensics?'},
#  {'translation_text': "I think it's on the line with our favorites."},
#  ...]

# %%
helsinki_translation_text = [text['translation_text'] for text in helsinki_translation]

# %%
helsinki_translation_text
# Out:
# ["It's been 10 years.",
#  "Some people can't let go.",
#  "That's the tool to stop it.",
#  'Breathe.',
#  'If you bring all your sisters to me,',
#  'Hey, sis.',
#  'Focus.',
#  'You read a book.',
#  'I took notes.',
#  'You work out like this.',
#  'All of you.',
#  'So what?',
#  'Breathe in.',
#  "I can't breathe.",
#  "I'm most worried about this guy.",
#  '(Laughter)',
#  "I'm so scared of his book.",
#  'Oh, my God.',
#  'Supported by',
#  "Ma'am, everyone says hello to Gott.",
#  'Hello. Hello.',
#  "Ma'am, you've seen a lot of teams today.",
#  "Um, I don't know if you have anything in common today.",
#  "That's it, that's it, that's it.",
#  "It's called Gayla, isn't it?",
#  "Now we're Gayla.",
#  'Trying to be social.',
#  "Gla's the other guy.",
#  "Today, you're asking us to go out with you.",
#  "Gaya's team is together.",
#  "Then we'll go together.",
#  'Not this scratch.',
#  '(Laughter)',
#  "Hello, sir. It's Whit.",
#  "Let's keep an eye on the subject right now.",
#  'Part of it.',
#  'And look at the whole picture, sir.',
#  "I'm Arm.",
#  'Now.',
#  "Gayla's media team.",
#  "It's too short. (Laughter)",
#  "Captain's name.",
#  "It's Gayla's team.",
#  'Create a Web site',
#  'And analyze the data a little bit.',
#  "Name's, uh...",
#  'Now continue.',
#  'Team Gala.',
#  'Rain has come in for an internship at Gaya.',
#  'In the lot.',
#  "Let's get this interview down to speed.",
#  "When you guys leave, he'll take you with him.",
#  "What I'm asking here is:",
#  'I got an idea.',
#  "Let's try out some ideas.",
#  "It's been months.",
#  'About',
#  "We're in a time of urgency.",
#  'We need to get up to work.',
#  "That's what I'm doing back there.",
#  "It's a lot of work.",
#  "Sometimes we're just doing our job.",
#  'I forgot about the development.',
#  'I wish we could.',
#  'Work, work, work, work, work.',
#  "Ask, when's the last time you worked out?",
#  'When was the last time you calmed down?',
#  'Reading.',
#  'When was the last time you added a brain?',
#  'When was the last time you recorded your experience?',
#  "We're going to be the ones who feel like running.",
#  'The exercise that we need is a lot of energy.',
#  "We feel like we're tired.",
#  'If you ask me if I work out a lot,',
#  "Not often, but it's a stretch.",
#  "It's raining. It doesn't take very much notes.",
#  "I'm asking if you like it.",
#  'Yeah.',
#  'Every time we get back to writing.',
#  'Talked to myself, kept a diary.',
#  'Or do you think about it every day?',
#  "But it's like...",
#  "We can't be consistent.",
#  'So it turns out,',
#  'Not much to write.',
#  'Captain likes to read.',
#  'But not for long.',
#  "Because there's a phone.",
#  '(Laughter)',
#  'Draw attention.',
#  "What's that?",
#  "It's time.",
#  'To make our lives more valuable.',
#  'What do you got?',
#  "One, it's a matter of the mind.",
#  "There's a body problem.",
#  "It's a matter of knowledge.",
#  "And then there's the memory.",
#  'Mind is meditation.',
#  'Focus.',
#  "As long as everyone's breathing.",
#  'You can all get your mind back on it.',
#  "I'm asking you why you're so focused.",
#  "So that's it.",
#  'To see your own thoughts.',
#  'My question is:',
#  "Who's got a hand?",
#  'If you raise your hand.',
#  'Is there anyone here?',
#  'Being distracted makes you tense.',
#  'Uh, okay, now.',
#  "Who's there?",
#  'Who knows how to deal with their own distraction.',
#  'Aah!',
#  'Rain. Sometimes.',
#  'Sometimes.',
#  "Who's here?",
#  'Who knows how to deal with constant distraction.',
#  "Rain, I know, but I don't do it all the time.",
#  'Yeah, yeah.',
#  "Rain, maybe you don't even know.",
#  'So at least we realize',
#  'Well, we are.',
#  'Was distracted.',
#  'Put yourself in a state of stress.',
#  "It's packed.",
#  'It needs to be released.',
#  'And then when we let it go,',
#  'Who was it?',
#  'People in front of us.',
#  'Everyone who came near us got hit.',
#  "So if we don't know how to stay calm,",
#  'From the distraction.',
#  "He won't let go. He won't let go.",
#  'And I said,',
#  'Is that out of the process?',
#  'Get out.',
#  "How'd it get out?",
#  'Wake up.',
#  'How do you feel?',
#  'Well, here it is.',
#  'Back to your breath.',
#  'When we come back to our senses,',
#  'Or do you feel in our wind?',
#  "We'll find out.",
#  'The idea stopped working.',
#  'And because we practice it a lot.',
#  "Working on it a lot, we'll find out.",
#  "It's breathing.",
#  'Oh, this breath.',
#  "Hey, I'm having this idea right now.",
#  "And they're not going to send it out to anyone else.",
#  "It'll come back to itself.",
#  'No effort.',
#  'To change my mind, too.',
#  'But watch it.',
#  "Let's see where it goes.",
#  'Music',
#  "Where's it going?",
#  "And then we'll finally see the nature of it.",
#  "It didn't last long.",
#  "It'll be over in a minute.",
#  'This is a matter of mental importance.',
#  'Physically.',
#  'Our bodies are full of organs.',
#  'We have an N.',
#  'We have bones.',
#  'We have muscle.',
#  'We have a lot of organs.',
#  'Everything.',
#  'The question is:',
#  'Do you need maintenance?',
#  'Did you lose it every day?',
#  "So, here's the deal.",
#  'We also need to focus on the body.',
#  'A lot of people work a lot.',
#  'And then spend the money in the hospital.',
#  'Because I forgot to look the other way.',
#  "Oh, really healthy. It's...",
#  'A great fortune.',
#  'Then we should know how to handle our bodies.',
#  "Next, it's the brain.",
#  "It's the brain. It's important.",
#  "It's a matter of thought.",
#  'To think about it, you need to have knowledge as a basis.',
#  "I can't figure it out because...",
#  "There's no knowledge.",
#  'Or just a few angles.',
#  "I haven't figured it out yet.",
#  "If there's a problem, it's at this level.",
#  'And our knowledge is at this level.',
#  "We can't fix this.",
#  'But if the problem is at this level,',
#  "And then we're adding more and more information.",
#  'In the end, we can ignore the problem.',
#  'That knowledge is a base.',
#  'Reading, listening is important.',
#  "And then there's the memory.",
#  'Yes, we have knowledge.',
#  "I'm listening.",
#  'And already learned.',
#  "But I don't remember.",
#  "Whit, I'm good at forgetting.",
#  "And what's the use of that? (Laughter)",
#  "In the end, it didn't get any good.",
#  "From the knowledge that you've wasted so much time reading.",
#  "So I'm thinking four things.",
#  'Is to concentrate.',
#  'Stand up. Stand up.',
#  'Reading.',
#  'Take notes.',
#  "I don't know what you're talking about.",
#  '15 minutes at a time.',
#  "But let's keep going every day.",
#  'Which is my challenge for everyone.',
#  'After today,',
#  'Seven days.',
#  'Seven days.',
#  "- Where's the camera? - Uh, okay.",
#  '(Laughter)',
#  "We'll interview you later.",
#  "That after seven days, there's enough to stick together.",
#  'What do his sisters get for themselves?',
#  "So it's a bit of a continuous process.",
#  "-Wick. -Oh, for me, there's a lot of pressure.",
#  'Because it has to be at least seven days.',
#  'To complete the routine.',
#  'This has, uh, in mind,',
#  "Hey, we'll have some free time.",
#  'To do something routine.',
#  "Is that what he's scheduled for?",
#  "Captain, I don't think it's gonna be okay.",
#  'It could be short on the third day.',
#  '4th, 5th, 6th.',
#  "Well, it's called four things, right?",
#  "Maybe there's something I didn't do.",
#  'Swindling, laughing.',
#  "Rain, if we're really busy, it's like an excuse.",
#  "Well, I can't do it for seven days.",
#  'Just in case, you know what?',
#  "Arm, we've been so busy.",
#  "We don't have much time.",
#  'And then to add a table to something.',
#  'Come into our lives again.',
#  "It's kind of like...",
#  "It's hard enough, too.",
#  "I'm not sure I'll get it.",
#  "Let's start with meditation.",
#  'Now when we meditate,',
#  'We will.',
#  'Stay focused on the area.',
#  'Right under your nose above your upper lip.',
#  "Because there's always going to be wind in and out of this area.",
#  "It's just...",
#  'We breathe unawares.',
#  "Let's just let it go automatically.",
#  "We'll only know if we know.",
#  "We're breathing hard, aren't we? It's breathing.",
#  "That's why we feel the wind coming in.",
#  'And the wind comes out.',
#  'How is that?',
#  "I'd like to invite everyone to try.",
#  'Try and focus on the area.',
#  'As much as possible.',
#  "And then we'll find it's not easy.",
#  'To do.',
#  'He thinks things. He thinks things.',
#  'But whatever you think.',
#  "Don't follow his ideas.",
#  "Don't worry about yourself.",
#  "Oh, my God, what's wrong with you?",
#  'No, no, no. Let it go. Let it go back to the wind.',
#  "You know you're coming back.",
#  "It's like an idea that's going to keep going.",
#  'Pow, come back.',
#  'Come back.',
#  'And watch your breath.',
#  "It's as natural as it is.",
#  "If it's going to take a short breath, let it breathe too short.",
#  "If it's going to take a long breath, let it take a long breath.",
#  'Okay.',
#  'Got it.',
#  'Shall we?',
#  'Come on.',
#  'Music',
#  "How'd it go? 15 minutes ago.",
#  'Share your experience.',
#  'What does that mean?',
#  '(Laughter)',
#  'Oh, shit.',
#  "It's crazy, isn't it? It's crazy, isn't it?",
#  'Are you out of your mind?',
#  "Captain, let's go.",
#  'Are you out of your mind?',
#  "Whit, you're up.",
#  'Are you out of your mind? Rain.',
#  "This one's not the best help, it's the best.",
#  'Uh-oh-oh. Like, uh-huh.',
#  'All the music, all the work, all the ideas.',
#  "I mean, it's a lot.",
#  'And then it turns out,',
#  "I can't concentrate.",
#  "And it's just a matter of time.",
#  'I want to open my eyes and write down my ideas.',
#  'Or, like, when is it going to be 15 minutes?',
#  'What the hell?',
#  "Rain. We feel we're still distracted.",
#  'And also...',
#  'It feels like time is running too slow.',
#  "Mm-hmm. When's 15 minutes?",
#  "Hey, look, there's something on our heads.",
#  "It's a story. It's a story.",
#  'And we will.',
#  'Back to your breath?',
#  "It's always going to fall off. It's like this.",
#  "And then it's back to focus. It's not very good.",
#  "And we're out of control, and we're out of control.",
#  "And we're like,",
#  'Afraid, uh...',
#  'Are we going to hang up or not?',
#  "While I'm sitting.",
#  'This is it. This is the problem.',
#  "We're using a mind that's distracted.",
#  'Living every day.',
#  "And we can't handle the inside.",
#  "We've become less focused on ourselves.",
#  "But that's how you practice it.",
#  'Just a little bit a day. A little bit a day. A little bit a day.',
#  "It's gonna be like driving a car.",
#  "We'll finally be able to drive.",
#  "We'll know which rhythm to break.",
#  'Which should be a turner.',
#  'Let go, let go',
#  "But if we don't know anything about this,",
#  "In the end, we're gonna become people.",
#  "All I know is what's out there.",
#  "But I don't know how to stop a mind that's distracted.",
#  'Because of this distraction.',
#  'It makes people.',
#  'Not happy at all.',
#  'Sleep.',
#  "I couldn't sleep.",
#  'Think, think, think, think.',
#  "I've been thinking.",
#  "I don't know what to stop thinking.",
#  'Looks like someone turned the radio on.',
#  "I don't know how to close it.",
#  'I ended up sleeping with a lot of ideas.',
#  "I'm tired of waking up.",
#  'No strength.',
#  'Why is it that the mind never gets a rest?',
#  'Rest of your body.',
#  "But my mind's tense.",
#  'Here.',
#  'Can anyone come back to their senses?',
#  '-Wish. -All right.',
#  'A little.',
#  "What's up?",
#  'Hey, I got it.',
#  '(Laughter)',
#  "That's good, that's good, that's good, that's good.",
#  'What about us?',
#  "It's almost as good as my brother's.",
#  'Yeah, a little bit, right?',
#  "It's okay. It's okay. It's okay.",
#  "It's like us.",
#  "I'm going to the grass in front of the house.",
#  'On the way.',
#  'I saw your shirt.',
#  "I'll grab my shirt and wash it.",
#  'Between the hallways to the wash.',
#  "Seeing the dishes haven't been washed, we'll do the dishes.",
#  'I can finish the dishes.',
#  "It's a call.",
#  'I saw this. I saw this right there.',
#  'Finally, continuous.',
#  'This is our idea.',
#  "I don't think I'm done with one thing.",
#  'So the tool to stop it is',
#  'Breathe.',
#  'A lot of practice.',
#  "Well, now that you've gone,",
#  '15 minutes a day.',
#  'I believe it was 15 minutes ago.',
#  "That's what everyone thought.",
#  'When are you going to be 15 minutes?',
#  'What took you so long?',
#  "There's a lot of stuff there, right?",
#  'There it is.',
#  "We're seeing that.",
#  'When we want something to happen,',
#  "And it's not what we want.",
#  "It's a hell of a pain.",
#  "It's so painful.",
#  "And then we'll learn our nature.",
#  'Well, the torture happened.',
#  'From our cravings.',
#  'Because I want it to run out of time.',
#  'Because I want it to be faster.',
#  "But time doesn't move any faster.",
#  'So I was miserable.',
#  "Let's share it. 15 minutes. How was your day?",
#  "My switch? That's what I'm talking about.",
#  'At first, I was thinking about it.',
#  "We're trying to hit it. We're trying to hit it.",
#  'Keep our breaths here.',
#  'We need to focus here.',
#  'We tried.',
#  'Hmm. Focus.',
#  "Like, you're always here.",
#  "I'll think about it soon enough.",
#  'Ah, go live with the water.',
#  'I heard water.',
#  'We circle back.',
#  'Try to get your focus back.',
#  "But at least it's good that we...",
#  'We know the point.',
#  'Well, where should I come back?',
#  "Uh, when's Whitman supposed to be back?",
#  "That's right. It's his.",
#  'At least we know that.',
#  'What point does it have to go back to?',
#  'This is his.',
#  "Whit, you're trying to give us this.",
#  'Stay focused.',
#  'The end of your nose is much more self-centered.',
#  'So what kind of activity do we do?',
#  'Trying to get us back on our own.',
#  'A lot of times.',
#  'We feel...',
#  "Hey, we're flowing.",
#  'To live in a social setting, or...',
#  'People meet in our everyday lives again.',
#  "We're going to focus on ourselves.",
#  "It's quite small.",
#  'But when I went with Gottp,',
#  'Gott makes us feel',
#  'We can come back to ourselves more easily.',
#  "That's all, sir.",
#  'And use it all day long.',
#  'Before we start.',
#  'Before work.',
#  'Before I focus on anything,',
#  'One minute.',
#  'Come back to your breath.',
#  'And take the power of focus for a second.',
#  "Let's get back to work.",
#  "Get in there. There's a problem.",
#  'Oh, my God. I got hit by a guy over there.',
#  "Shut down the comms. We'll be gone in a minute.",
#  'To the park.',
#  'You can do it with your eyes open.',
#  'Come back to your breath.',
#  "When we're thinking about subtracting.",
#  'Our breaths will change.',
#  "It's not light, it's sick.",
#  "I can't even hold the wind.",
#  'Any part of the body is tense.',
#  'Such as?',
#  "It'll take me a while to figure it out.",
#  'Let go!',
#  'Let go!',
#  "There's gonna be some tension.",
#  "That's why we're so slow.",
#  'Found the natural truth:',
#  'How are mental stress affecting the body?',
#  'So we can see that back in the wind.',
#  'Hey, guys, breathe like this.',
#  "Which means what we're thinking is going to happen.",
#  "There's a process coming back to check it out.",
#  "How's it going?",
#  "Captain, it's going to raise its voice in the past.",
#  "It's like there's a sound coming in.",
#  "That's a little bit of luck. That's a guy's voice.",
#  'What he said, it came back.',
#  'We get confused, and then...',
#  'Back to your breath.',
#  'And a little sneer.',
#  'When we got back to the wind,',
#  "Hey, it doesn't hurt. We don't get to focus there.",
#  "You can't sit when you're normal.",
#  "There's a little bit of sarcasm.",
#  'With so much energy, so much sleep.',
#  'It makes us a lot easier.',
#  'Calm down.',
#  "I know it's not sleeping.",
#  "I didn't know it was the light on my face.",
#  'Or what?',
#  "It's more breathing.",
#  'It feels like an experience.',
#  "Better than when you're sitting on your own.",
#  'Yes.',
#  "Actually, it's almost everyone's problem.",
#  "We've been pushed by our past thoughts to make us miserable.",
#  "Despite what it's been through,",
#  "But we can't put the thought down.",
#  "Because we don't know how to focus.",
#  'With current moment',
#  'The breath is the present moment.',
#  "When we don't find a way to focus on the current breath,",
#  "What's the follow-up?",
#  'We get pulled over by the past.',
#  "It's been 10 years.",
#  "Some people can't let go.",
#  'Oh, come on.',
#  "I won't let you in next life.",
#  '(Laughter)',
#  "Someone's got it that way.",
#  'But if people get this,',
#  "I'll be sure to know.",
#  "Oh, we're running after what's already dead.",
#  'In the meantime,',
#  'Some suffer from an unborn future.',
#  "Whether you're miserable in the past or in the future that hasn't happened.",
#  'It can go back from this cycle.',
#  'By going back.',
#  'This is the present.',
#  'We have legs. We have legs.',
#  'We were taken by the thought of the past.',
#  "- Give us don't like it. - Don't like it.",
#  "But in the end, when we're back in the present,",
#  "We'll find out there's nothing in the present.",
#  "We've already been through that.",
#  "It's easy to teach. It's easy.",
#  'little by little, little by little.',
#  'Oh, my God, you were like this before.',
#  "He's got a body in him.",
#  "Oh, my God, that's what I said.",
#  'Hmm.',
#  'When I see him,',
#  'Still carrying that thought.',
#  "Doesn't look at him with the eyes of the present.",
#  'We change every day.',
#  "Why can't someone who does something bad to us change?",
#  "But we're not used to being present.",
#  'So we judge him with a picture of the past.',
#  'At the same time, some of us like it a lot.',
#  "Oh, this one's good. It's good. It's good.",
#  "Maybe they're bad these days.",
#  "We're still changing.",
#  "That's why we need to train ourselves.",
#  'Back to the present.',
#  'So we can see each other.',
#  'In fact, in the present, it really is.',
#  "How's it going?",
#  "Hey, I've seen a movie.",
#  "And what's the movie we're looking at? It's imaginary.",
#  "That's a good point. Keep going.",
#  'Hey, and we can imagine the movie we saw.',
#  "It's like this. It's like this.",
#  "And then we're back to focus.",
#  "And he's out.",
#  "I feel like I'm on a movie show.",
#  'The movie we watched, it came in.',
#  "That's a good point.",
#  "That's where we see it.",
#  'How do our addictions affect our minds?',
#  'And the good thing is,',
#  "Once we've imagined and we've come to our senses,",
#  'I told you.',
#  'Even the people around me or the people from far away said,',
#  'Picking a drug.',
#  'What are you looking at? What are you listening to?',
#  'Filters',
#  'Because it does.',
#  'So much for our thinking system.',
#  "Once we're back in the game, we'll focus on the present.",
#  "In the end, what we're using won't get in.",
#  "It's coming in.",
#  'Pull us out of the present moment to imagine.',
#  "See, what we're really into is a lot of stuff.",
#  'To life.',
#  "Whether it's food.",
#  "It's all about the text.",
#  "Whether it's about the video,",
#  'Whatever.',
#  'Yeah. How many?',
#  "It'll only find a way out.",
#  "But that's exactly what day it's gonna come out of.",
#  "That's it.",
#  'Good.',
#  "How's it going?",
#  "It's raining, and...",
#  "Do you feel like, hey, why it's been over 15 minutes?",
#  '(Laughter)',
#  'And then I talked to him, like,',
#  'The idea came through, but...',
#  "We know we're losing our minds.",
#  'But I wanted to talk to myself.',
#  "Let's talk. Okay, here's the thing.",
#  "- When we're done, - Okay.",
#  'Come back for a fresh breath.',
#  "That's good, that's good, that's good.",
#  'What the hell is 15 minutes of this?',
#  "Actually, it's a pain.",
#  "It's a grudge.",
#  "It's hard to concentrate.",
#  'If we get too sleepy,',
#  'Too distracted.',
#  "And you don't have to interpret that.",
#  "I'm upset because I've been sitting here a long time.",
#  'Because time is too much.',
#  "I just know I'm upset.",
#  'And look at this frustration.',
#  'How does that affect your breath?',
#  "That's all.",
#  "You're coming back.",
#  "Arm, it's really nice of us to make a decision.",
#  'To ask you something, Got.',
#  'And he gave me the tools to say,',
#  'That we are?',
#  'Trying to stop the idea.',
#  'More than observation.',
#  "What it's like.",
#  'Or where it took us.',
#  'We feel like this device just made sense that day.',
#  "That's what it makes us feel like.",
#  "Uh, today's coming.",
#  'It makes us complete.',
#  "And it's really a technique to go home.",
#  "Okay, so here's the bottom line:",
#  'Each one of them.',
#  "Just now, as far as I'm concerned.",
#  'Got one thing for sure.',
#  "It's about coming back to you.",
#  'And knowing',
#  "I'm working on it right now.",
#  "That's exactly what this is.",
#  "Most people think they don't know what they're thinking.",
#  "Now we've got the secret.",
#  "I know I'm thinking.",
#  '15 minutes of practice every morning.',
#  'Right away, wake up.',
#  "Let's concentrate.",
#  "Don't touch the phone.",
#  "Don't read yet.",
#  "Don't do anything yet.",
#  'Wash your face, wash your eyes, call it freshness.',
#  '15 minutes in the morning.',
#  "It's breathing.",
#  'Focus on breathing in and out.',
#  "I can't wait to scrub my legs.",
#  'You can sit in a chair.',
#  'Lie down and do this.',
#  'Because if you do this,',
#  "I'll be late for work.",
#  '(Laughter)',
#  "It's gonna be a long time.",
#  'Oh, we forgot one thing.',
#  'After every meditation,',
#  'Best wishes.',
#  'Create an atmosphere in our room.',
#  'After we calm down,',
#  'Send your best wishes.',
#  'Thank you.',
#  "The work we've done.",
#  'A colleague who works with us.',
#  'Four factors, anything that makes us comfortable.',
#  'Every penny we have.',
#  'Thank you.',
#  'I appreciate it.',
#  'And then as we keep doing this,',
#  "We'll find one chicken pan.",
#  'Thank you very much.',
#  'Because our hearts are about to get more detailed.',
#  "We'll start seeing that.",
#  "By the time the rice's in our dishes,",
#  'How many times has it been?',
#  "There's a lot of places to go.",
#  "Because we're more thorough.",
#  'So we can look at things a little bit more carefully.',
#  'Thank you. Thank you. Thank you.',
#  "And we'll be happy with that.",
#  "I'm asking you, maybe the first part doesn't work all the time.",
#  'But at least...',
#  '10 days, maybe one day.',
#  '(Laughter)',
#  "That's it.",
#  'Rain. Thank you, Got. (Laughter)',
#  'Thank you. Thank you.',
#  "We'll take care of it.",
#  'Easy before you go to work.',
#  '15 minutes.',
#  "Okay, let's get started.",
#  'Let me see this one.',
#  "I'm most worried about this guy.",
#  'Captain, why did he choose us?',
#  "We feel like, uh, we have a problem, don't we?",
#  "I'm almost sick of anything.",
#  'If we go to the park,',
#  "We'll be like...",
#  'Ama.',
#  "He's very strong.",
#  'Mm-hmm.',
#  "That's why you have your own gym at home.",
#  "Because you're playing outside.",
#  "They say you're crazy.",
#  '(Laughter)',
#  'Music. The day I wake up.',
#  'A song. A day to stand again.',
#  'Music is enough to lose.',
#  'Music is enough to let anyone',
#  'Music, everything.',
#  'Music',
#  'The thick voice comes from both our friends and his friends.',
#  "That he's changed.",
#  'I mean, he likes guys.',
#  'And think about who we like.',
#  'Bring your face closer.',
#  "Everybody's been deaf.",
#  "What's he saying? We're like this.",
#  'Hello. Welcome to the orange soft.',
#  "It's February. What's it like?",
#  "It'll be the day of the sacrifice.",
#  "Valentine's Day.",
#  "That's what love is all about.",
#  'So this is calculating.',
#  'How many people in your head right now?',
#  "I'm trying to figure out who to tell the story.",
#  'We can have our first love many times.',
#  'First love.',
#  "My heart's broken.",
#  'I know my age right away.',
#  "It's not love, everybody.",
#  "But it's kind of a fuse.",
#  'It happened in a brand-new Chang in elementary school.',
#  'I had a crush on one of my seniors.',
#  "Since he's in fifth grade, we're in fourth grade.",
#  "You're so young. You're so young.",
#  'We remember that time was fourth grade.',
#  'To be a cheerleader.',
#  "And we can't dance.",
#  "And he's, like, a senior with the same color.",
#  "And he's the one who taught us how to dance.",
#  '5th graders',
#  "Yeah, I'm five years old. I'm a four-year-old.",
#  '12123 12121',
#  "And we're just so grateful for the way things are.",
#  "He's very interested in the way other brothers teach.",
#  'But this brother, like I taught him on purpose,',
#  "That's why it's so impressive that he cares about us.",
#  'And we secretly like him.',
#  "It's when we moved to all the girls' schools.",
#  "Here's to middle school, where this is a high school.",
#  "And in the past, we've never known each other.",
#  'With a creature called a man.',
#  'Which is where we went to school.',
#  "It's a school of art.",
#  "Is that there's a pattern.",
#  'The guy who majored in music, the music major, the guitar major.',
#  'The guy with the guitar is a handsome guy.',
#  'All right, everybody?',
#  "And we're really into the current.",
#  'And a lot of people like him.',
#  "Yeah, I'd love that.",
#  "Because people like it so much, they'll like it.",
#  'A friend of the same class.',
#  "He's in seventh grade. He's still in the same school.",
#  'And then we go up 6th.',
#  'And our friend, he knows we like it.',
#  'Our friend took care of our phone.',
#  'And text. Here.',
#  "It's a flirt.",
#  "I'm not hitting on you. I'm not hitting on you.",
#  "All I'm saying is, of course, we're going to have to break in because...",
#  "We're the little guys he's got. There's a whole school likes it.",
#  "We're just this much and we're like,",
#  "I'll do whatever I can for this guy.",
#  'Look at this. What the hell?',
#  "And that's when we saw this little movie called Love.",
#  'Is that...',
#  "I'm the brother of Sean's water.",
#  "It's in a little thing with the mammary polishing and the type.",
#  'The water is all for you.',
#  "It's Drummeyer for you to turn around.",
#  'This is it. This is it. This is it.',
#  'Remember, my friend with the lyrics.',
#  "It's the song in the album.",
#  'You want to hear it?',
#  'Her heart is calling for her.',
#  'Something very long.',
#  'And then he sent it back, so what the hell did he have to talk about?',
#  "And there's a chance we'll be together.",
#  'Well, that was my first boyfriend in the sixth grade.',
#  'I remember we were trying to, like,',
#  "Put yourself where he's found.",
#  "All of Thailand's high school kids have to go through this.",
#  "The guy who likes it, he's gonna have a place in the cafeteria, right?",
#  "We're gonna have to walk through there a lot.",
#  "Or maybe this is room one, right? And he's in room seven.",
#  "We're gonna go to the bathroom.",
#  'One day, ten times in the bathroom.',
#  'Walk by, walk by.',
#  'Walk through it, walk through it, walk through it.',
#  'Look at it with your heart.',
#  'Let us feel that this is the drive to my school.',
#  "It's the same as this guy, people.",
#  'Keep trying to get in his way.',
#  "That's what makes him see us all the time.",
#  'This is what happened.',
#  'I remember a scene he was walking by with a friend, and he was like,',
#  "It's like coming near us and saying something to us.",
#  'And think about who we like.',
#  'Bring your face closer.',
#  "And I don't remember what he said, but I do.",
#  'The shot he took brought his face closer and closer.',
#  'Like a fuse.',
#  "He's with a friend and he's just like us.",
#  "And then you talk to us nearby, and it's like,",
#  "Everybody's been deaf.",
#  "What's he saying? We're like this.",
#  "What did he say? I didn't hear anything.",
#  'I mean, we look at his face and we feel like...',
#  'Love. This is love.',
#  "Yeah, well, it's kind of embarrassing, everybody.",
#  'We felt it at the time.',
#  'To get close to a man.',
#  'Well, back then, it was just a guy with his hand on his shoulder.',
#  "I can't. I'll tell you to marry him.",
#  "I said don't touch a man, okay?",
#  "But it's when they bring their faces closer to us.",
#  "We feel like we're gonna walk into his hand and say we're a couple.",
#  "But I couldn't, because I was still embarrassed and didn't have the courage.",
#  'Still want to be friends.',
#  "I don't know why, because he already knows we like him.",
#  'Leave it to the kids of this generation, if you like.',
#  "Don't play with me like that.",
#  "It's good to be a friend.",
#  'No, I like it. Tell me you like it. Let him know.',
#  'Well, at least let it be known that a life has to say what we think it is.',
#  'How can you be so angry?',
#  'We moved to Bangkok to sing, etc.',
#  "Life's too busy with the contest.",
#  "Because it's on TV every week. It's practice dancing.",
#  "It's supposed to be a duet. It's got to be a show.",
#  "Turns out they're kind of separated.",
#  'And we heard a thick voice.',
#  'Our friends and his friends.',
#  "That he's changed something.",
#  "But he's changed in here, which means he likes men.",
#  "That's what I'm saying.",
#  "I mean, we're bad radar. We're still broken.",
#  'And I remember the four years we talked about.',
#  "That means we're dating.",
#  "I've had this fight with my friends, and I've barely talked to my friends because",
#  "Dude, I'm trying to warn you.",
#  "I've got a friend here to warn me.",
#  'My friends are trying to tell me that, you know,',
#  "I don't think so.",
#  'So this has to be said.',
#  "It's been a long time since we liked him since first grade.",
#  'And then, like, a lot of comics, a lot of movies, and we felt like,',
#  "A life. I'm gonna have to tell him I love him.",
#  'At least let him know',
#  'Do you have him in your heart?',
#  'So that day, I bought him some earpieces.',
#  'And then I walked up.',
#  'And then he handed it to him, and he said,',
#  'I like you, and then I run out.',
#  "The speed at which it's very awkward.",
#  "That's what happened. Didn't listen to what he said.",
#  'Not listening, not ready to listen.',
#  "I'm telling you, this is what you want.",
#  "And here's the conclusion:",
#  "I'm not seeing him anymore.",
#  "He's got someone he likes, too.",
#  "So they're apart from each other.",
#  "But there's a bit of a problem here.",
#  'On the day he left at third grade, right?',
#  "We're still in school, and when we get into high school,",
#  'We had a chance to talk to him again on Facebook.',
#  "And he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's... he's...",
#  "He's hitting on us.",
#  "Turns out he's hitting on us now when we were in high school.",
#  "Which is why we're happy. We're very happy.",
#  'But it turns out that we...',
#  "It's like we talked about it and it's like it's not a match.",
#  "We haven't felt that.",
#  'What does a relationship have to do with a boyfriend?',
#  'And then we went ahead and asked him what kind of person he was.',
#  'Hey, can we just, like, clear this up?',
#  'Whether or not it is.',
#  "But then he was on the phone, and he said he wasn't.",
#  'He likes girls.',
#  'So we feel that if he says he likes women,',
#  "We're gonna have to trust our own people, you know?",
#  'Finally, when we started hearing about what kind of man he liked,',
#  'So we started looking into it.',
#  "There's a point where that range uses Hi5.",
#  "- Hi, what's up? - Yeah.",
#  'We remember where important people will be.',
#  "If it's not the first one, it's the middle one.",
#  'Well, either the first or the middle.',
#  'We were the first.',
#  'What about when we went to the competition?',
#  "We've got a hip-five going around, don't we?",
#  'And then we just noticed, uh, in the middle of it, it turns people.',
#  'Suddenly, it turned into a junior.',
#  "This guy's got a clue.",
#  "I mean, it's really cute and it's like, you know, it's like, you know, it's like, you know, it's like, you know, you know, you're like, you know, you're like, you know, you're like, you're like, you know, you're like, you're like, you know, you're like, you're like, you know, you're like, you're like, you're like, you're like, you're like, you're like, you're kind of, you know, like, you're kind of, like, kind of, like, kind of, like, you know, like, you know, you know, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, like, like, like, like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, like, you're like, like, like, like, you're like, you're like, you're like, like, like, like, like, like, you're like, you're like, you're like, you're like, you're like, like, you're like, like, like, like, like, like, like, like, like, like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, you're like, like, you're like, you're like, you're like, you're like, you're like, you're",
#  "It's a couple of levels of age apart.",
#  'How the hell did they get to know each other?',
#  'Why is it in the middle of something?',
#  'After the contest ended, we started looking into it.',
#  'Start calling his friends.',
#  "Just to be honest, I'd like to be honest with you.",
#  "What's going on while we're gone?",
#  'So I finally realized, "Oh, okay."',
#  'I mean, he should have a body that likes men.',
#  'So we broke up with him.',
#  "And frankly, we didn't tell him why we broke up that day.",
#  'Oh, and, uh...',
#  'We have a surprise today.',
#  "No, but it's been a long time.",
#  "I'm still friends with him on Facebook these days.",
#  "That's what it's like for our first love.",
#  "What do you give? It's actually a lot of money.",
#  "It's a good memory for us since we were kids.",
#  "I mean, even if we like him, we're not dating him.",
#  "But that's what got us all dressed up.",
#  'Get up and do it. Get up and take care of yourself.',
#  "It's an inspiration to go to school every day.",
#  'Yes.',
#  "It's kind of fun.",
#  "I mean, if we don't have this one back,",
#  "I mean, we're gonna be living like, like,",
#  'Study, study, study, study.',
#  'What kind of study is this kid supposed to do?',
#  "But when he's got all the men, he's got the energy to keep his life active.",
#  "Which I'm not saying everyone's like this, okay?",
#  "Some people learn one thing and they're happy, okay?",
#  'Time will help us get to know ourselves.',
#  "The distance that's going on or anything, it just makes people kind of",
#  'You can review and grow up and get to know yourself.',
#  'Today he gets to know himself better.',
#  'We all get to know ourselves a little bit better.',
#  "In the end, it's going to be a lesson for both of them.",
#  "Once we have a new relationship, we'll have a new relationship.",
#  "So we're going to kind of take lessons and kind of use them in a way.",
#  'What the hell does love continue to live for?',
#  "We believe everyone's sitting with their friends.",
#  "It's about the past we've been sorry about.",
#  'What if we come back here and tell you the story?',
#  "It's going to be very funny.",
#  "And we're gonna laugh at our friends about why I'm doing this.",
#  'What have you done?',
#  "That's how everyone remembers.",
#  'And it makes us beautiful to this day.',
#  "You've got a face. You've got a curse on you.",
#  "I said I was too tough. I'm sorry.",
#  "At first we didn't have the guts to tell them because they were so young, people would be like,",
#  "She's been a slut since 12.",
#  "What the hell? It's so young.",
#  'But we only love you, Odd.',
#  'This is one more time for the PreviewPoP.',
#  "I didn't come to sign.",
#  "Because we're talking about a murder.",
#  'Hello, doctor. Hello, Pop.',
#  "I didn't come to sign the papers. I'm serious.",
#  "Because I didn't come. I mean, I did.",
#  "Let's try it.",
#  '- How to murder someone? - Yes.',
#  "We're just talking about examples of what's happened in the world, sir.",
#  'But first, I need to get to know the money doctor.',
#  "You're a real doctor, aren't you?",
#  "He's a real doctor.",
#  "It's when you graduate from med school.",
#  'And go to medical school to slow your age.',
#  'Sexual and clinical medicine.',
#  "I'm just interested in crime.",
#  "If you're not mistaken, it's med school.",
#  'What kind of stuff?',
#  '- A few of them. - Yes, sir.',
#  'Because when we went to med school, we took a lot of classes.',
#  'Many branches like this, sir.',
#  "It's the principal's surgery.",
#  "Or in high school, there's going to be a separate course.",
#  "It's forensics.",
#  "That's about the autopsy.",
#  'Or, hey, look at all this criminal evidence.',
#  'But according to your studies, medicine slows you down.',
#  "- with the murders, it's pretty isolated. - Yeah.",
#  "- Actually, the doctor's check, right? - Yeah.",
#  "Now we're going to use the capital.",
#  "I have an experience with the M.E.'s office.",
#  'And finally, right then.',
#  "We're going to study in the field we're interested in.",
#  "It's about beauty. It's about aging.",
#  'But on the other side of our lives.',
#  'Are we the ones who are interested or the ones who are attracted to us?',
#  '- The story of the investigation. - Oh.',
#  "That's why I'm interested in that, too.",
#  "But I didn't go to any forensics class. Mm.",
#  "It's just a partial feeling. We're interested.",
#  "And I'd like to learn something like that.",
#  "So it's like two sides.",
#  "I understand that if we're interested in the investigation,",
#  "What's wrong with being there, M.E.?",
#  'Or forensics?',
#  "I think it's on the line with our favorites.",
#  ...]

# %%
data = {
    'helsinki_translation': helsinki_translation_text,
    'nllb_translation': nllb_translation
}

translated_df = pd.DataFrame(data)

# %%
translated_df
# Out:
#                                     helsinki_translation  \
# 0                                    It's been 10 years.
# 1                              Some people can't let go.
# 2                            That's the tool to stop it.
# 3                                               Breathe.
# 4                   If you bring all your sisters to me,
# ...                                                  ...
# 19063               And we can afford it. We can pay it.
# 19064           And what changed our financial behavior?
# 19065  Tell me a little bit about where we're going t...
# 19066                    That's going to happen in 2025.
# 19067               When did you decide to end the band?
#
#                                         nllb_translation
# 0                                   It's been ten years.
# 1                              Some people can't let go.
# 2                            That's the tool to stop it.
# 3                                              The wind.
# 4            If you bring all your brothers and sisters,
# ...                                                  ...
# 19063                        And we can pay. We can pay.
# 19064            So what changed our financial behavior?
# 19065  Let me tell you a little bit about how we're t...
# 19066                    That's going to happen in 2025.
# 19067        It's about when you decide to end the band.
#
# [19068 rows x 2 columns]

# %%
import evaluate 

meteor = evaluate.load('meteor')

def compute_meteor(row, col1, col2):
    meteor_score = meteor.compute(predictions=[row[col1],], references=[row[col2],])
    return meteor_score['meteor']

meteor_scores = translated_df.apply(lambda row : compute_meteor(row, 'helsinki_translation', 'nllb_translation'), axis = 1)
meteor_scores.describe()
# Out:
# [nltk_data] Downloading package wordnet to /home/dhuser/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/dhuser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/dhuser/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# count    19068.000000
# mean         0.541398
# std          0.260823
# min          0.000000
# 25%          0.338442
# 50%          0.543820
# 75%          0.738955
# max          0.999953
# dtype: float64

# %%
translated_df['meteor_scores'] = meteor_scores

# %%
bleu = evaluate.load("bleu")

# %%
def compute_bleu(row, col1, col2):
    # Extract the hypothesis and reference
    hypothesis = row[col1]
    reference = row[col2]

    # Check for empty hypothesis or reference
    if not hypothesis or not reference:
        return 0.0

    # Compute BLEU score
    bleu_score = bleu.compute(predictions=[hypothesis], references=[[reference]])
    return bleu_score['bleu']

bleu_scores = translated_df.apply(lambda row : compute_bleu(row, 'helsinki_translation', 'nllb_translation'), axis = 1)
bleu_scores.describe()
# Out:
# count    19068.000000
# mean         0.171685
# std          0.283124
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.311709
# max          1.000000
# dtype: float64

# %%
translated_df['bleu_scores'] = bleu_scores
translated_df_filtered = translated_df[translated_df['meteor_scores']> 0.9]

# %%
import random

def randomly_pick_translation(row):
    def flip(p):
        return 'H' if random.random() < p else 'T'
    
    translation_col = ''
    if flip(0.5) == 'H':
        translation_col = 'helsinki_translation'
    else:
        translation_col = 'nllb_translation'

    return row[translation_col]

english_translations = translated_df_filtered.apply(randomly_pick_translation, axis = 1)

# %%
combined_df['meteor_scores'] = meteor_scores

# %%
combined_df_filtered = combined_df[combined_df['meteor_scores'] > 0.9]

# %%
combined_df_filtered.apply(lambda x : x['end_time'] - x['start_time'], axis = 1).sum()
# Out:
# 3774.0000000000045

# %%
combined_df_filtered['eng_reference'] = english_translations
# Out:
# /tmp/ipykernel_19238/973878818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df_filtered['eng_reference'] = english_translations

# %%
combined_df_filtered
# Out:
#          file_name  start_time  end_time                      eng_reference  \
# 0      sVnGI2S_OuA       0.000     1.768                It's been 10 years.
# 1      sVnGI2S_OuA       1.768     2.869          Some people can't let go.
# 2      sVnGI2S_OuA       2.869     4.938        That's the tool to stop it.
# 14     sVnGI2S_OuA      21.921    22.856        I'm worried about this guy.
# 18     sVnGI2S_OuA      29.462    32.132                       Supported by
# ...            ...         ...       ...                                ...
# 19040  eVbLXknPOdk       4.360     7.200      I think when we retire at 40,
# 19041  eVbLXknPOdk       7.840     9.120                   We have to live.
# 19052  eVbLXknPOdk      44.080    46.280  I want you to see it right there.
# 19057  eVbLXknPOdk      55.280    57.800    I've seen something new before.
# 19066  eVbLXknPOdk      86.880    89.120    That's going to happen in 2025.
#
#                           thai_reference  \
# 0           เหตุการณ์มันผ่านมาแล้ว 10 ปี
# 1                       บางคนปล่อยไม่ได้
# 2      นั้นเครื่องมือที่จะหยุดมันได้ คือ
# 14                  ผมห่วงคนนี้ที่สุดเลย
# 18                           สนับสนุนโดย
# ...                                  ...
# 19040     ผมคิดว่าเมื่อเราเกษียณไปตอน 40
# 19041                  เราต้องมีชีวิตต่อ
# 19052              อยากให้มองเห็นตรงนั้น
# 19057             เมื่อก่อนเห็นอะไรใหม่ๆ
# 19066        ที่กำลังจะเกิดขึ้นในปี 2025
#
#                               trimmed_segment_path  meteor_scores
# 0       data/sub/sVnGI2S_OuA_trimmed_segment_1.wav       0.997685
# 1       data/sub/sVnGI2S_OuA_trimmed_segment_2.wav       0.998542
# 2       data/sub/sVnGI2S_OuA_trimmed_segment_3.wav       0.999023
# 14     data/sub/sVnGI2S_OuA_trimmed_segment_15.wav       0.974418
# 18     data/sub/sVnGI2S_OuA_trimmed_segment_19.wav       0.937500
# ...                                            ...            ...
# 19040   data/sub/eVbLXknPOdk_trimmed_segment_2.wav       0.999023
# 19041   data/sub/eVbLXknPOdk_trimmed_segment_3.wav       0.996000
# 19052  data/sub/eVbLXknPOdk_trimmed_segment_14.wav       0.933957
# 19057  data/sub/eVbLXknPOdk_trimmed_segment_19.wav       0.998542
# 19066  data/sub/eVbLXknPOdk_trimmed_segment_28.wav       0.999023
#
# [1914 rows x 7 columns]

# %%
combined_df_filtered.to_csv("train_1.csv")

# %%
# Get a list of all files in the directory
all_files = os.listdir("data/sub/")  # Replace "data/sub/" with your directory path

# Extract just the filenames from the DataFrame file paths
df_filenames = combined_df_filtered['trimmed_segment_path'].apply(lambda x: os.path.basename(x))

# Filter out files that are not in the DataFrame
files_to_remove = [file for file in all_files if file not in df_filenames.values]

# Remove the files not in the DataFrame
for file in files_to_remove:
    os.remove(os.path.join("data/sub/", file))  # Replace "data/sub/" with your directory path
