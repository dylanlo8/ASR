# %%
#! pip install git+https://github.com/openai/whisper.git
#! pip install numpy torch pandas urllib3 torchaudio scipy tqdm matplotlib transformers deepcut jiwer pydub evaluate
#! pip install tf-keras

# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import torch
import pandas as pd
from pydub import AudioSegment
from transformers import pipeline
import string

from scipy.io import wavfile
from tqdm.notebook import tqdm

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Preprocessing Audio and Subtitles Files

# %%
# Retrieve .txt files
def list_files_in_directory(directory):
    file_list = []
    for filename in os.listdir(directory):
        # Only pick up files with .txt extensions (transcript)
        if filename.endswith(".txt"):
            file_list.append(filename.replace(".txt", ""))
    return file_list

# Create the dataframe
def get_reference_df(directory, audio_txt_file):
    txt_file_path = os.path.join(directory, audio_txt_file + ".txt")
    columns = ["start_time", "end_time", "reference"]
    # Read the text file into a DataFrame
    df = pd.read_csv(txt_file_path, sep="\t", header=None, names=columns, quoting=3)

    # Add file name
    df.insert(0, 'file_name', pd.Series([audio_txt_file] * len(df)))

    # Remove quotation marks
    df['reference'] = df['reference'].apply(lambda x : x.replace('"',""))
    
    return df

# Trim audio files
def trim_wav_by_timestamps(directory, wav_file_name, reference_df):
    # Create the output directory if it doesn't exist
    output_dir = "data/sub/"
    os.makedirs(output_dir, exist_ok=True)
    wav_file = os.path.join(directory, wav_file_name + ".wav") # get into data file
    
    # Load the WAV file
    audio = AudioSegment.from_wav(wav_file)
    
    def trim_segments(row):
        start_ms = float(row['start_time']) * 1000  # Convert start time to milliseconds
        end_ms = float(row['end_time']) * 1000      # Convert end time to milliseconds
        trimmed_segment = audio[start_ms:end_ms]
    
        return trimmed_segment
    
    # Iterate over timestamps and trim the audio
    for i, row in reference_df.iterrows():
        trimmed_segment = trim_segments(row)
        output_file = os.path.join(output_dir, wav_file_name + "_" f"trimmed_segment_{i+1}.wav")
        trimmed_segment.export(output_file, format="wav")
        reference_df.at[i, 'trimmed_segment_path'] = output_file
    
    return reference_df

def strip_punctuation(text):
    # Define a regex pattern to remove punctuation
    punctuation_pattern = re.compile(r'[^\w\s]')
    return punctuation_pattern.sub('', text)

def filter_subs_by_lang(reference_df):
    # Helper function that is applied across the rows to filter English text only
    
    def filter_english_only(text):
        # Define a regex pattern to match English words with punctuations
        english_pattern = re.compile(r'\b[A-Za-z][A-Za-z\'\-]*\b')
        # Find all English words in the text
        english_words = english_pattern.findall(text)
        # Join the English words into a single string
        english_text = ' '.join(english_words)
        return english_text
    
    def filter_thai_only(text):
        # Tokenize the string, split by spaces
        list_of_words = text.split()
        # Define a regex pattern to match English words with punctuations
        english_pattern = re.compile(r'\b[A-Za-z][A-Za-z\'\-]*\b')
        # Find all English words in the text
        english_words = english_pattern.findall(text)
        # Remove punctuation from the list of words
        list_of_words = [strip_punctuation(word) for word in list_of_words]
        # Find all Thai words
        thai_words = [word for word in list_of_words if strip_punctuation(word) not in english_words]
        # Concatenate the Thai words into a string
        thai_text = ' '.join(thai_words)
        # Return Thai string
        return thai_text

    reference_df['eng_reference'] = reference_df['reference'].apply(filter_english_only)
    reference_df['thai_reference'] = reference_df['reference'].apply(filter_thai_only)

    return reference_df


def get_combined_audio_table(directory, file_names):
    combined_df = pd.DataFrame()
    for file_name in file_names:
        # Reads the transcript dataframe which has the start_time, end_time of each transcript
        reference_df = get_reference_df(directory, file_name)

        # Split subtitles by language
        reference_df = filter_subs_by_lang(reference_df)

        # Remove 'reference' column
        reference_df = reference_df.drop('reference', axis=1)

        # Uncomment to trim all the .wav file according to the subtitles start_time and end_time
        reference_df = trim_wav_by_timestamps(directory, file_name, reference_df)
        
        # Append the processed DataFrame to the combined DataFrame
        combined_df = pd.concat([combined_df, reference_df], ignore_index=True)

        # Comment out this section if not required
        #combined_df = combined_df.drop(['file_name', 'start_time', 'end_time'], axis=1)
    
    return combined_df

directory = os.path.join(os.getcwd(), "data/train")
file_names = list_files_in_directory(directory)
combined_df_train = get_combined_audio_table(directory, file_names)
combined_df_train
# Out:
#         file_name  start_time  end_time  \
# 0     DU_s5HDJc0w       8.839    13.818
# 1     DU_s5HDJc0w      14.228    18.711
# 2     DU_s5HDJc0w      19.445    21.321
# 3     DU_s5HDJc0w      21.669    26.559
# 4     DU_s5HDJc0w      26.760    28.899
# ...           ...         ...       ...
# 2408  EoBVsX--qz8    1259.847  1262.269
# 2409  EoBVsX--qz8    1262.269  1264.449
# 2410  EoBVsX--qz8    1265.109  1266.776
# 2411  EoBVsX--qz8    1266.776  1269.002
# 2412  EoBVsX--qz8    1269.002  1271.440
#
#                                           eng_reference  \
# 0     Episode This episode we will be inviting a fam...
# 1     but this will be the first time that we will b...
# 2              and it s going to be the first time also
# 3     that this episode will be done in bilingual wi...
# 4                                          Good morning
# ...                                                 ...
# 2408                    Please like share and subscribe
# 2409                  Chollada Channel Chollada Channel
# 2410                                                Bye
# 2411                    Please like share and subscribe
# 2412     Chollada Channel Kae a Kae at Chollada Channel
#
#                                       thai_reference  \
# 0             คำนด นจะไดตอนรบคนทแวะ เวยนมาบอยพอสมควร
# 1     แตนจะเปนครงแรก ทเราจะไดนงคยกนรปแบบวดโอเตมรปแบบ
# 2                                 its และยงเปนครงแรก
# 3                           ทจะเปนพดสองภาษากบแขกทานน
# 4                             พดจดาว วฒนปกรณ สวสดครบ
# ...                                              ...
# 2408                    ดแลวชอบ กดไลก แชร ซบสไครบดวย
# 2409                                           กบ คะ
# 2410                                             บาย
# 2411                   อยาลมกดไลก กดแชร หรอวาซบสไครบ
# 2412                                       กบเกอะแกท
#
#                               trimmed_segment_path
# 0       data/sub/DU_s5HDJc0w_trimmed_segment_1.wav
# 1       data/sub/DU_s5HDJc0w_trimmed_segment_2.wav
# 2       data/sub/DU_s5HDJc0w_trimmed_segment_3.wav
# 3       data/sub/DU_s5HDJc0w_trimmed_segment_4.wav
# 4       data/sub/DU_s5HDJc0w_trimmed_segment_5.wav
# ...                                            ...
# 2408  data/sub/EoBVsX--qz8_trimmed_segment_412.wav
# 2409  data/sub/EoBVsX--qz8_trimmed_segment_413.wav
# 2410  data/sub/EoBVsX--qz8_trimmed_segment_414.wav
# 2411  data/sub/EoBVsX--qz8_trimmed_segment_415.wav
# 2412  data/sub/EoBVsX--qz8_trimmed_segment_416.wav
#
# [2413 rows x 6 columns]

# %%
combined_df_train[:50]
# Out:
#       file_name  start_time  end_time  \
# 0   DU_s5HDJc0w       8.839    13.818
# 1   DU_s5HDJc0w      14.228    18.711
# 2   DU_s5HDJc0w      19.445    21.321
# 3   DU_s5HDJc0w      21.669    26.559
# 4   DU_s5HDJc0w      26.760    28.899
# 5   DU_s5HDJc0w      28.899    30.591
# 6   DU_s5HDJc0w      30.720    35.480
# 7   DU_s5HDJc0w      35.604    37.271
# 8   DU_s5HDJc0w      37.271    41.545
# 9   DU_s5HDJc0w      41.545    46.773
# 10  DU_s5HDJc0w      46.947    51.246
# 11  DU_s5HDJc0w      51.916    56.474
# 12  DU_s5HDJc0w      57.591    61.528
# 13  DU_s5HDJc0w      62.074    63.850
# 14  DU_s5HDJc0w      64.049    69.475
# 15  DU_s5HDJc0w      69.475    73.163
# 16  DU_s5HDJc0w      73.734    75.337
# 17  DU_s5HDJc0w      75.337    79.894
# 18  DU_s5HDJc0w      79.894    82.703
# 19  DU_s5HDJc0w      82.703    89.247
# 20  DU_s5HDJc0w      90.210    97.951
# 21  DU_s5HDJc0w      97.951   101.232
# 22  DU_s5HDJc0w     101.232   102.000
# 23  DU_s5HDJc0w     102.000   106.324
# 24  DU_s5HDJc0w     106.324   109.903
# 25  DU_s5HDJc0w     110.745   112.873
# 26  DU_s5HDJc0w     112.873   115.906
# 27  DU_s5HDJc0w     117.768   122.150
# 28  DU_s5HDJc0w     122.771   125.706
# 29  DU_s5HDJc0w     125.706   128.568
# 30  DU_s5HDJc0w     129.114   133.100
# 31  DU_s5HDJc0w     133.348   135.620
# 32  DU_s5HDJc0w     136.315   141.550
# 33  DU_s5HDJc0w     141.873   144.306
# 34  DU_s5HDJc0w     144.629   150.428
# 35  DU_s5HDJc0w     150.602   154.355
# 36  DU_s5HDJc0w     155.230   157.967
# 37  DU_s5HDJc0w     157.967   163.865
# 38  DU_s5HDJc0w     164.337   167.874
# 39  DU_s5HDJc0w     168.793   169.851
# 40  DU_s5HDJc0w     169.851   172.546
# 41  DU_s5HDJc0w     172.546   178.121
# 42  DU_s5HDJc0w     178.121   181.466
# 43  DU_s5HDJc0w     181.466   183.307
# 44  DU_s5HDJc0w     183.307   186.125
# 45  DU_s5HDJc0w     186.125   188.125
# 46  DU_s5HDJc0w     190.608   193.680
# 47  DU_s5HDJc0w     193.680   198.968
# 48  DU_s5HDJc0w     198.968   203.801
# 49  DU_s5HDJc0w     204.893   209.859
#
#                                         eng_reference  \
# 0   Episode This episode we will be inviting a fam...
# 1   but this will be the first time that we will b...
# 2            and it s going to be the first time also
# 3   that this episode will be done in bilingual wi...
# 4                                        Good morning
# 5                                        Good morning
# 6   Actually I ve heard that you give lectures in ...
# 7                                       Yes sometimes
# 8   Because you went to get your education in Brit...
# 9   Yes I got my MA in London So yeah sometimes I ...
# 10     The thing that I learned from you is listening
# 11  Apply Listening is something that can really b...
# 12                 At first I though listening really
# 13  On the other hand speaking it s more understan...
# 14  It s more understandable with choice of words ...
# 15         There are many things and tactics involved
# 16                                 But with listening
# 17      Is there really anything to it If I have ears
# 18                      I can listen that s all right
# 19  Oh was I wrong I was so wrong to think that it...
# 20  And I only just found out from you and others ...
# 21  there is a bib session to teach for example th...
# 22                                       I teach that
# 23  Deep Listening Right You teach Deep Listening ...
# 24  So can we talk a little about that because I w...
# 25                 What do you teach at these classes
# 26            I teach how to listen to another person
# 27  Most of the time people don t know whether the...
# 28      Everybody thinks that OK I know how to listen
# 29     but in fact they don t know how to listen well
# 30  So we start right from like how to set the bod...
# 31               That helps you to be a good listener
# 32  How to be attentive and how to maintain focus ...
# 33     Try not to interrupt like empathetic listening
# 34  You try not to interrupt and you listen more a...
# 35  And you just go along with the story like feel...
# 36  Yeah and try not to interrupt That s empatheti...
# 37  It s good for any situation where there s a lo...
# 38  when someone is angry you got to like let Like...
# 39                                      Let them vent
# 40                        Exactly vent and everything
# 41  Or if that person is sad or overwhelmed you do...
# 42       Just let it flow That s empathetic listening
# 43           That s already difficult for some people
# 44  Yeah because it doesn t look like your doing a...
# 45             or it doesn t look like you re helping
# 46  And you feel like you re supposed to help the ...
# 47  Like they come to you and cry and they re like...
# 48  They re suffering obviously and you want to do...
# 49  You want to do something That s your own need ...
#
#                                        thai_reference  \
# 0              คำนด นจะไดตอนรบคนทแวะ เวยนมาบอยพอสมควร
# 1      แตนจะเปนครงแรก ทเราจะไดนงคยกนรปแบบวดโอเตมรปแบบ
# 2                                  its และยงเปนครงแรก
# 3                            ทจะเปนพดสองภาษากบแขกทานน
# 4                              พดจดาว วฒนปกรณ สวสดครบ
# 5                                              สวสดคะ
# 6   จรงๆ เคยไดยนพดาวสอนหรอวาเลคเชอรเปน ภาษาองกฤษอย...
# 7                                         มบาง มบางคะ
# 8                          เพราะคณเรยบจบจากองกฤษใชไหม
# 9        ใชคะ เรยบจบปโททกรงลอนดอน มสอนเปนภาษาองกฤษบาง
# 10           สงเรยนรแลวพดาววนนงเนย คอเรองของการฟงแหละ
# 11             เรองของการฟง ละผมรสกวามนมา กบชวตไดจรงๆ
# 12                ตอนแรกเราอาจจะมความรสกวา สกลฟงเนยนะ
# 13                         สมมตสกลพด เราเขาใจไดวา its
# 14             คณตองรจกใชคำพด ใชนำเสยง ใชอวจนภาษา Its
# 15                      มนมหลายสกลทเกยวของ มแทกตกตางๆ
# 16                                         แตแบบสกลฟง
# 17                         มนมหรอวะกถามหแลวยงไดยนเสยง
# 18                        กแปลวาฟงไดแลวไมใชเหรอ thats
# 19                       คดผด ผดทคดวาการฟงเปนเรองงายๆ
# 20  แลวกพงรจากพดาวดวย จากคนอนๆ ดวย วามนเปนสงทบางทเ...
# 21                  มบบมเซชนในการไปสอนการ เชน มการแบบ
# 22                                             เราสอน
# 23          ใชไหมพดาวสอนอยแบบ สำหรบผบรหาร อะไรอยางเนย
# 24                     เรามาคยกนหนอยไดไหมเพราะฉนอยากร
# 25                             คณสอนอะไรในชนเรยนเหลาน
# 26                                      ฉนสอนวธฟงคนอน
# 27                    dont คนสวนใหญไมรวาเขาฟงเปนหรอไม
# 28                          ทกคนคดวา โอเค ฉนฟงคนอนเปน
# 29                       dont แตจรงๆ แลวพวกเขาฟงไมเปน
# 30          were ดงนนเราจงเรมจาก ภาษากายเวลาเราฟงคนอน
# 31                                มนชวยใหคณเปนผฟงทดได
# 32                 วธการใสใจและวธการรกษาโฟกสไปทบคคลอน
# 33                  พยายามอยาขดจงหวะ ฟงอยางเหนอกเหนใจ
# 34  พยายามไมขดจงหวะและฟงมากเยอะๆ แลวคณจะรบรถงความร...
# 35                           และคณกแคตามนำไปกบเรองราว
# 36  Thats ใช พยายามอยาขดจงหวะ นนคอการฟงอยางเหนอกเหนใจ
# 37  Its theres มนดกบทกสถานการณทมการปลดปลอยอารมณออก...
# 38               แบบเพอนโกรธ เวลามใครโกรธอะไร เรากตอง
# 39                                  ปลอยใหพวกเขาระบาย
# 40                               ใชเลย ระบายออกทกอยาง
# 41               dont หรอถาคนนนเศราหรอทวมทนกอยาไปขดขน
# 42  Thats ปลอยใหมนไหลไปตามธรรมชาต นนเปนการรบฟงอยาง...
# 43               Thats ซงแคนกเปนเรองทยากสำหรบบางคนแลว
# 44             doesnt ใช เพราะมนดเหมอนคณไมไดทำอะไรเลย
# 45             doesnt youre หรอดเหมอนคณไมไดชวยอะไรเลย
# 46           youre และเราจะรสกวา เราควรชวยคนตรงหนาเรา
# 47   theyre เชน มคนมาหาคณแลวรองไหใส เหมอนทกอยางพงพนาศ
# 48  Theyre เหนไดชดวาพวกเขากำลงทกขทรมาน แลวคณกอยากจ...
# 49  Thats persons คณอยากชวย นนคอความตองการของคณเอง...
#
#                            trimmed_segment_path
# 0    data/sub/DU_s5HDJc0w_trimmed_segment_1.wav
# 1    data/sub/DU_s5HDJc0w_trimmed_segment_2.wav
# 2    data/sub/DU_s5HDJc0w_trimmed_segment_3.wav
# 3    data/sub/DU_s5HDJc0w_trimmed_segment_4.wav
# 4    data/sub/DU_s5HDJc0w_trimmed_segment_5.wav
# 5    data/sub/DU_s5HDJc0w_trimmed_segment_6.wav
# 6    data/sub/DU_s5HDJc0w_trimmed_segment_7.wav
# 7    data/sub/DU_s5HDJc0w_trimmed_segment_8.wav
# 8    data/sub/DU_s5HDJc0w_trimmed_segment_9.wav
# 9   data/sub/DU_s5HDJc0w_trimmed_segment_10.wav
# 10  data/sub/DU_s5HDJc0w_trimmed_segment_11.wav
# 11  data/sub/DU_s5HDJc0w_trimmed_segment_12.wav
# 12  data/sub/DU_s5HDJc0w_trimmed_segment_13.wav
# 13  data/sub/DU_s5HDJc0w_trimmed_segment_14.wav
# 14  data/sub/DU_s5HDJc0w_trimmed_segment_15.wav
# 15  data/sub/DU_s5HDJc0w_trimmed_segment_16.wav
# 16  data/sub/DU_s5HDJc0w_trimmed_segment_17.wav
# 17  data/sub/DU_s5HDJc0w_trimmed_segment_18.wav
# 18  data/sub/DU_s5HDJc0w_trimmed_segment_19.wav
# 19  data/sub/DU_s5HDJc0w_trimmed_segment_20.wav
# 20  data/sub/DU_s5HDJc0w_trimmed_segment_21.wav
# 21  data/sub/DU_s5HDJc0w_trimmed_segment_22.wav
# 22  data/sub/DU_s5HDJc0w_trimmed_segment_23.wav
# 23  data/sub/DU_s5HDJc0w_trimmed_segment_24.wav
# 24  data/sub/DU_s5HDJc0w_trimmed_segment_25.wav
# 25  data/sub/DU_s5HDJc0w_trimmed_segment_26.wav
# 26  data/sub/DU_s5HDJc0w_trimmed_segment_27.wav
# 27  data/sub/DU_s5HDJc0w_trimmed_segment_28.wav
# 28  data/sub/DU_s5HDJc0w_trimmed_segment_29.wav
# 29  data/sub/DU_s5HDJc0w_trimmed_segment_30.wav
# 30  data/sub/DU_s5HDJc0w_trimmed_segment_31.wav
# 31  data/sub/DU_s5HDJc0w_trimmed_segment_32.wav
# 32  data/sub/DU_s5HDJc0w_trimmed_segment_33.wav
# 33  data/sub/DU_s5HDJc0w_trimmed_segment_34.wav
# 34  data/sub/DU_s5HDJc0w_trimmed_segment_35.wav
# 35  data/sub/DU_s5HDJc0w_trimmed_segment_36.wav
# 36  data/sub/DU_s5HDJc0w_trimmed_segment_37.wav
# 37  data/sub/DU_s5HDJc0w_trimmed_segment_38.wav
# 38  data/sub/DU_s5HDJc0w_trimmed_segment_39.wav
# 39  data/sub/DU_s5HDJc0w_trimmed_segment_40.wav
# 40  data/sub/DU_s5HDJc0w_trimmed_segment_41.wav
# 41  data/sub/DU_s5HDJc0w_trimmed_segment_42.wav
# 42  data/sub/DU_s5HDJc0w_trimmed_segment_43.wav
# 43  data/sub/DU_s5HDJc0w_trimmed_segment_44.wav
# 44  data/sub/DU_s5HDJc0w_trimmed_segment_45.wav
# 45  data/sub/DU_s5HDJc0w_trimmed_segment_46.wav
# 46  data/sub/DU_s5HDJc0w_trimmed_segment_47.wav
# 47  data/sub/DU_s5HDJc0w_trimmed_segment_48.wav
# 48  data/sub/DU_s5HDJc0w_trimmed_segment_49.wav
# 49  data/sub/DU_s5HDJc0w_trimmed_segment_50.wav

# %%
directory = os.path.join(os.getcwd(), "data/test/")

file_names = list_files_in_directory(directory)
combined_df = get_combined_audio_table(directory, file_names)
combined_df
# Out:
#        file_name  start_time  end_time  \
# 0    2OF_N9xQOAc       0.000     3.118
# 1    2OF_N9xQOAc       3.118     4.909
# 2    2OF_N9xQOAc       4.909     6.129
# 3    2OF_N9xQOAc       6.129     7.498
# 4    2OF_N9xQOAc       7.498     8.827
# ..           ...         ...       ...
# 592  b4o5YC_wMXM    1019.264  1022.082
# 593  b4o5YC_wMXM    1022.107  1025.358
# 594  b4o5YC_wMXM    1025.383  1027.521
# 595  b4o5YC_wMXM    1027.546  1029.461
# 596  b4o5YC_wMXM    1029.587  1031.468
#
#                                    reference  \
# 0                 Right now I m in Singapore
# 1    Most people when they come to Singapore
# 2                   They come to eat dim sum
# 3                              Visit Merlion
# 4                            Visit Universal
# ..                                       ...
# 592    Please press like share and subscribe
# 593     If you want me to take you somewhere
# 594              to eat or do any activities
# 595               you can leave me a comment
# 596                  Until next time Bye bye
#
#                              trimmed_segment_path
# 0      data/sub/2OF_N9xQOAc_trimmed_segment_1.wav
# 1      data/sub/2OF_N9xQOAc_trimmed_segment_2.wav
# 2      data/sub/2OF_N9xQOAc_trimmed_segment_3.wav
# 3      data/sub/2OF_N9xQOAc_trimmed_segment_4.wav
# 4      data/sub/2OF_N9xQOAc_trimmed_segment_5.wav
# ..                                            ...
# 592  data/sub/b4o5YC_wMXM_trimmed_segment_348.wav
# 593  data/sub/b4o5YC_wMXM_trimmed_segment_349.wav
# 594  data/sub/b4o5YC_wMXM_trimmed_segment_350.wav
# 595  data/sub/b4o5YC_wMXM_trimmed_segment_351.wav
# 596  data/sub/b4o5YC_wMXM_trimmed_segment_352.wav
#
# [597 rows x 5 columns]

# %%
combined_df['segment_duration'] = combined_df.apply(lambda x : x['end_time'] - x['start_time'], axis = 1)

# %%
combined_df['segment_duration'].describe() # All audio segments are under 10s
# Out:
# count    597.000000
# mean       2.282425
# std        1.008288
# min        0.596000
# 25%        1.563000
# 50%        2.079000
# 75%        2.833000
# max        6.487000
# Name: segment_duration, dtype: float64

# %%
combined_df['segment_duration'].sum()
# Out:
# 1362.6079999999988

# %% [markdown]
# ## Direct Translation with Whisper

# %%
import whisper

model = whisper.load_model("medium")

# %%
language = "Thai"
options = dict(language=language, beam_size=5, best_of=5)
translate_options = dict(task="translate", **options)

# %%
def map_transcription(row):
    segment_wavfile = row['trimmed_segment_path']
    transcription = model.transcribe(segment_wavfile, **translate_options)['text']
    return transcription

# %%
transcriptions = combined_df.apply(map_transcription, axis=1)

# %%
combined_df['hypothesis'] = transcriptions

# %%
combined_df
# Out:
#        file_name  start_time  end_time  \
# 0    2OF_N9xQOAc       0.000     3.118
# 1    2OF_N9xQOAc       3.118     4.909
# 2    2OF_N9xQOAc       4.909     6.129
# 3    2OF_N9xQOAc       6.129     7.498
# 4    2OF_N9xQOAc       7.498     8.827
# ..           ...         ...       ...
# 592  b4o5YC_wMXM    1019.264  1022.082
# 593  b4o5YC_wMXM    1022.107  1025.358
# 594  b4o5YC_wMXM    1025.383  1027.521
# 595  b4o5YC_wMXM    1027.546  1029.461
# 596  b4o5YC_wMXM    1029.587  1031.468
#
#                                    reference  \
# 0                 Right now I m in Singapore
# 1    Most people when they come to Singapore
# 2                   They come to eat dim sum
# 3                              Visit Merlion
# 4                            Visit Universal
# ..                                       ...
# 592    Please press like share and subscribe
# 593     If you want me to take you somewhere
# 594              to eat or do any activities
# 595               you can leave me a comment
# 596                  Until next time Bye bye
#
#                              trimmed_segment_path  segment_duration  \
# 0      data/sub/2OF_N9xQOAc_trimmed_segment_1.wav             3.118
# 1      data/sub/2OF_N9xQOAc_trimmed_segment_2.wav             1.791
# 2      data/sub/2OF_N9xQOAc_trimmed_segment_3.wav             1.220
# 3      data/sub/2OF_N9xQOAc_trimmed_segment_4.wav             1.369
# 4      data/sub/2OF_N9xQOAc_trimmed_segment_5.wav             1.329
# ..                                            ...               ...
# 592  data/sub/b4o5YC_wMXM_trimmed_segment_348.wav             2.818
# 593  data/sub/b4o5YC_wMXM_trimmed_segment_349.wav             3.251
# 594  data/sub/b4o5YC_wMXM_trimmed_segment_350.wav             2.138
# 595  data/sub/b4o5YC_wMXM_trimmed_segment_351.wav             1.915
# 596  data/sub/b4o5YC_wMXM_trimmed_segment_352.wav             1.881
#
#                                            hypothesis
# 0                               But I hate Singapore!
# 1                               See you in Singapore!
# 2                                  Let's eat som tam.
# 3                               Let's see Aon's hand.
# 4
# ..                                                ...
# 592   Please like, share and subscribe to my channel.
# 593                    If you want me to take you out
# 594                           Where should I go next?
# 595                     Feel free to leave a comment.
# 596          Don't forget to subscribe to my channel.
#
# [597 rows x 7 columns]

# %%
# Using Whisper that is finetuned on Thai Speech Datasets
MODEL_NAME = "biodatlab/whisper-th-medium-combined"  
lang = "th"

device = 0 if torch.cuda.is_available() else "cpu"

pipe = pipeline(
    task="automatic-speech-recognition",
    model=MODEL_NAME,
    chunk_length_s=30,
    device=device,
)
# Out:
# /home/dhuser/Desktop/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def map_transcription_finetuned_asr(row, pipe):
    segment_wavfile = row['trimmed_segment_path']
    transcription = pipe(
        segment_wavfile, 
        generate_kwargs={"language":"<|th|>", "task":"translate"}, 
        batch_size=16
    )["text"]
    
    return transcription

# %%
transcriptions_finetuned = combined_df.apply(lambda row: map_transcription_finetuned_asr(row, pipe), axis=1)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
transcriptions_finetuned
# Out:
# 0                                 Now I'm in Singapore!
# 1               I'm going to Singapore with my friends.
# 2                                      Let's eat tipsum
# 3                                Let's see Lion's Hand!
# 4                                     It's a universal.
#                              ...
# 592     Press like, share and subscribe for me as well.
# 593                      If you want me to go on a trip
# 594                           Where can I eat and play?
# 595                             You can leave a comment
# 596                                             Bye bye
# Length: 597, dtype: object

# %%
combined_df['hypothesis_finetuned'] = transcriptions_finetuned
combined_df
# Out:
#        file_name  start_time  end_time  \
# 0    2OF_N9xQOAc       0.000     3.118
# 1    2OF_N9xQOAc       3.118     4.909
# 2    2OF_N9xQOAc       4.909     6.129
# 3    2OF_N9xQOAc       6.129     7.498
# 4    2OF_N9xQOAc       7.498     8.827
# ..           ...         ...       ...
# 592  b4o5YC_wMXM    1019.264  1022.082
# 593  b4o5YC_wMXM    1022.107  1025.358
# 594  b4o5YC_wMXM    1025.383  1027.521
# 595  b4o5YC_wMXM    1027.546  1029.461
# 596  b4o5YC_wMXM    1029.587  1031.468
#
#                                    reference  \
# 0                 Right now I m in Singapore
# 1    Most people when they come to Singapore
# 2                   They come to eat dim sum
# 3                              Visit Merlion
# 4                            Visit Universal
# ..                                       ...
# 592    Please press like share and subscribe
# 593     If you want me to take you somewhere
# 594              to eat or do any activities
# 595               you can leave me a comment
# 596                  Until next time Bye bye
#
#                              trimmed_segment_path  segment_duration  \
# 0      data/sub/2OF_N9xQOAc_trimmed_segment_1.wav             3.118
# 1      data/sub/2OF_N9xQOAc_trimmed_segment_2.wav             1.791
# 2      data/sub/2OF_N9xQOAc_trimmed_segment_3.wav             1.220
# 3      data/sub/2OF_N9xQOAc_trimmed_segment_4.wav             1.369
# 4      data/sub/2OF_N9xQOAc_trimmed_segment_5.wav             1.329
# ..                                            ...               ...
# 592  data/sub/b4o5YC_wMXM_trimmed_segment_348.wav             2.818
# 593  data/sub/b4o5YC_wMXM_trimmed_segment_349.wav             3.251
# 594  data/sub/b4o5YC_wMXM_trimmed_segment_350.wav             2.138
# 595  data/sub/b4o5YC_wMXM_trimmed_segment_351.wav             1.915
# 596  data/sub/b4o5YC_wMXM_trimmed_segment_352.wav             1.881
#
#                                            hypothesis  \
# 0                               But I hate Singapore!
# 1                               See you in Singapore!
# 2                                  Let's eat som tam.
# 3                               Let's see Aon's hand.
# 4
# ..                                                ...
# 592   Please like, share and subscribe to my channel.
# 593                    If you want me to take you out
# 594                           Where should I go next?
# 595                     Feel free to leave a comment.
# 596          Don't forget to subscribe to my channel.
#
#                                  hypothesis_finetuned
# 0                               Now I'm in Singapore!
# 1             I'm going to Singapore with my friends.
# 2                                    Let's eat tipsum
# 3                              Let's see Lion's Hand!
# 4                                   It's a universal.
# ..                                                ...
# 592   Press like, share and subscribe for me as well.
# 593                    If you want me to go on a trip
# 594                         Where can I eat and play?
# 595                           You can leave a comment
# 596                                           Bye bye
#
# [597 rows x 8 columns]

# %%
import string

def strip_punctuation(text):
    # Create a translation table that maps each punctuation character to None
    translator = str.maketrans('', '', string.punctuation)
    # Use the translation table to remove all punctuation from the text
    return text.translate(translator)

# %%
combined_df['hypothesis'] = combined_df['hypothesis'].apply(strip_punctuation).apply(lambda x : x.strip())
combined_df['hypothesis_finetuned'] = combined_df['hypothesis_finetuned'].apply(strip_punctuation).apply(lambda x : x.strip())

# %%
combined_df
# Out:
#        file_name  start_time  end_time  \
# 0    2OF_N9xQOAc       0.000     3.118
# 1    2OF_N9xQOAc       3.118     4.909
# 2    2OF_N9xQOAc       4.909     6.129
# 3    2OF_N9xQOAc       6.129     7.498
# 4    2OF_N9xQOAc       7.498     8.827
# ..           ...         ...       ...
# 592  b4o5YC_wMXM    1019.264  1022.082
# 593  b4o5YC_wMXM    1022.107  1025.358
# 594  b4o5YC_wMXM    1025.383  1027.521
# 595  b4o5YC_wMXM    1027.546  1029.461
# 596  b4o5YC_wMXM    1029.587  1031.468
#
#                                    reference  \
# 0                 Right now I m in Singapore
# 1    Most people when they come to Singapore
# 2                   They come to eat dim sum
# 3                              Visit Merlion
# 4                            Visit Universal
# ..                                       ...
# 592    Please press like share and subscribe
# 593     If you want me to take you somewhere
# 594              to eat or do any activities
# 595               you can leave me a comment
# 596                  Until next time Bye bye
#
#                              trimmed_segment_path  segment_duration  \
# 0      data/sub/2OF_N9xQOAc_trimmed_segment_1.wav             3.118
# 1      data/sub/2OF_N9xQOAc_trimmed_segment_2.wav             1.791
# 2      data/sub/2OF_N9xQOAc_trimmed_segment_3.wav             1.220
# 3      data/sub/2OF_N9xQOAc_trimmed_segment_4.wav             1.369
# 4      data/sub/2OF_N9xQOAc_trimmed_segment_5.wav             1.329
# ..                                            ...               ...
# 592  data/sub/b4o5YC_wMXM_trimmed_segment_348.wav             2.818
# 593  data/sub/b4o5YC_wMXM_trimmed_segment_349.wav             3.251
# 594  data/sub/b4o5YC_wMXM_trimmed_segment_350.wav             2.138
# 595  data/sub/b4o5YC_wMXM_trimmed_segment_351.wav             1.915
# 596  data/sub/b4o5YC_wMXM_trimmed_segment_352.wav             1.881
#
#                                         hypothesis  \
# 0                             But I hate Singapore
# 1                             See you in Singapore
# 2                                 Lets eat som tam
# 3                               Lets see Aons hand
# 4
# ..                                             ...
# 592  Please like share and subscribe to my channel
# 593                 If you want me to take you out
# 594                         Where should I go next
# 595                   Feel free to leave a comment
# 596         Dont forget to subscribe to my channel
#
#                               hypothesis_finetuned
# 0                              Now Im in Singapore
# 1            Im going to Singapore with my friends
# 2                                  Lets eat tipsum
# 3                              Lets see Lions Hand
# 4                                  Its a universal
# ..                                             ...
# 592  Press like share and subscribe for me as well
# 593                 If you want me to go on a trip
# 594                       Where can I eat and play
# 595                        You can leave a comment
# 596                                        Bye bye
#
# [597 rows x 8 columns]

# %%
from evaluate import load

wer = load("wer")
wer_score = wer.compute(predictions=combined_df['hypothesis'], references=combined_df['reference'])
print("Word Error Rate:", wer_score)
# Out:
# Word Error Rate: 0.9452316076294278

# %%
wer = load("wer")
wer_score = wer.compute(predictions=combined_df['hypothesis'], references=transcriptions_finetuned)
print("Word Error Rate:", wer_score)
# Out:
# Word Error Rate: 0.9441959531416401

# %% [markdown]
# ## CER

# %%
cer = load("cer")
cer_score = cer.compute(predictions=combined_df['hypothesis'], references=combined_df['reference'])
print("Character Error Rate:", cer_score)
# Out:
# Character Error Rate: 0.7598657562782085

# %%
cer_score_finetuned = cer.compute(predictions=combined_df['hypothesis'], references=transcriptions_finetuned)
print("Character Error Rate (Finetuned):", cer_score_finetuned)
# Out:
# Character Error Rate (Finetuned): 0.7792978261832028

# %% [markdown]
# ## Meteor Score

# %%
import evaluate 

meteor = evaluate.load('meteor')
# Out:
# [nltk_data] Downloading package wordnet to /home/dhuser/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/dhuser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/dhuser/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def compute_meteor(row, hypothesis_column, reference_column):
    meteor_score = meteor.compute(predictions=[row[hypothesis_column],], references=[row[reference_column],])
    return meteor_score['meteor']

meteor_scores_whisper = combined_df.apply(lambda row : compute_meteor(row, 'hypothesis', 'reference'), axis = 1)
meteor_scores_whisper.describe()
# Out:
# count    597.000000
# mean       0.193621
# std        0.238468
# min        0.000000
# 25%        0.000000
# 50%        0.102041
# 75%        0.328488
# max        0.996000
# dtype: float64

# %%
meteor_scores_whisper_finetuned = combined_df.apply(lambda row : compute_meteor(row, 'hypothesis_finetuned', 'reference'), axis = 1)
meteor_scores_whisper_finetuned.describe()
# Out:
# count    597.000000
# mean       0.225605
# std        0.228305
# min        0.000000
# 25%        0.050000
# 50%        0.142857
# 75%        0.368056
# max        0.996000
# dtype: float64

# %% [markdown]
# ## Bleu Scores

# %%
bleu = evaluate.load("bleu")

# %%
def compute_bleu(row, hypothesis_column, reference_column):
    # Extract the hypothesis and reference
    hypothesis = row[hypothesis_column]
    reference = row[reference_column]

    # Check for empty hypothesis or reference
    if not hypothesis or not reference:
        return 0.0

    # Compute BLEU score
    bleu_score = bleu.compute(predictions=[hypothesis], references=[[reference]])
    return bleu_score['bleu']

bleu_scores_whisper = combined_df.apply(lambda row : compute_bleu(row, 'hypothesis', 'reference'), axis = 1)
bleu_scores_whisper.describe()
# Out:
# count    597.000000
# mean       0.022754
# std        0.108430
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# dtype: float64

# %%
bleu_scores_whisper
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 592    0.365555
# 593    0.840896
# 594    0.000000
# 595    0.000000
# 596    0.000000
# Length: 597, dtype: float64

# %%
combined_df
# Out:
#        file_name  start_time  end_time  \
# 0    2OF_N9xQOAc       0.000     3.118
# 1    2OF_N9xQOAc       3.118     4.909
# 2    2OF_N9xQOAc       4.909     6.129
# 3    2OF_N9xQOAc       6.129     7.498
# 4    2OF_N9xQOAc       7.498     8.827
# ..           ...         ...       ...
# 592  b4o5YC_wMXM    1019.264  1022.082
# 593  b4o5YC_wMXM    1022.107  1025.358
# 594  b4o5YC_wMXM    1025.383  1027.521
# 595  b4o5YC_wMXM    1027.546  1029.461
# 596  b4o5YC_wMXM    1029.587  1031.468
#
#                                    reference  \
# 0                 Right now I m in Singapore
# 1    Most people when they come to Singapore
# 2                   They come to eat dim sum
# 3                              Visit Merlion
# 4                            Visit Universal
# ..                                       ...
# 592    Please press like share and subscribe
# 593     If you want me to take you somewhere
# 594              to eat or do any activities
# 595               you can leave me a comment
# 596                  Until next time Bye bye
#
#                              trimmed_segment_path  segment_duration  \
# 0      data/sub/2OF_N9xQOAc_trimmed_segment_1.wav             3.118
# 1      data/sub/2OF_N9xQOAc_trimmed_segment_2.wav             1.791
# 2      data/sub/2OF_N9xQOAc_trimmed_segment_3.wav             1.220
# 3      data/sub/2OF_N9xQOAc_trimmed_segment_4.wav             1.369
# 4      data/sub/2OF_N9xQOAc_trimmed_segment_5.wav             1.329
# ..                                            ...               ...
# 592  data/sub/b4o5YC_wMXM_trimmed_segment_348.wav             2.818
# 593  data/sub/b4o5YC_wMXM_trimmed_segment_349.wav             3.251
# 594  data/sub/b4o5YC_wMXM_trimmed_segment_350.wav             2.138
# 595  data/sub/b4o5YC_wMXM_trimmed_segment_351.wav             1.915
# 596  data/sub/b4o5YC_wMXM_trimmed_segment_352.wav             1.881
#
#                                         hypothesis  \
# 0                             But I hate Singapore
# 1                             See you in Singapore
# 2                                 Lets eat som tam
# 3                               Lets see Aons hand
# 4
# ..                                             ...
# 592  Please like share and subscribe to my channel
# 593                 If you want me to take you out
# 594                         Where should I go next
# 595                   Feel free to leave a comment
# 596         Dont forget to subscribe to my channel
#
#                               hypothesis_finetuned
# 0                              Now Im in Singapore
# 1            Im going to Singapore with my friends
# 2                                  Lets eat tipsum
# 3                              Lets see Lions Hand
# 4                                  Its a universal
# ..                                             ...
# 592  Press like share and subscribe for me as well
# 593                 If you want me to go on a trip
# 594                       Where can I eat and play
# 595                        You can leave a comment
# 596                                        Bye bye
#
# [597 rows x 8 columns]

# %%
bleu_scores_whisper_finetuned = combined_df.apply(lambda row : compute_bleu(row, 'hypothesis_finetuned', 'reference'), axis = 1)
bleu_scores_whisper_finetuned.describe()
# Out:
# count    597.00000
# mean       0.01289
# std        0.08359
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        1.00000
# dtype: float64
